# %%
import folium
from mapping import mapper

# %%
mapper = mapper()

# %%
m = mapper.mapHighways([42.228708, -84.575065], [42.344618, -84.294575])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edec2398bea4442d2e4fd5db13a52be1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edec2398bea4442d2e4fd5db13a52be1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edec2398bea4442d2e4fd5db13a52be1 = L.map(
#                 &quot;map_edec2398bea4442d2e4fd5db13a52be1&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f59a1d53efca055da8850d4e596b152 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_edec2398bea4442d2e4fd5db13a52be1);
#
#
#             var poly_line_8a718364d8a49c43049d2b06a49d9aaa = L.polyline(
#                 [[42.2767394, -84.3586325], [42.2771861, -84.358675]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_edec2398bea4442d2e4fd5db13a52be1);
#
#
#         var popup_814891390dfa3e7554ae3457f0cdfd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec2f460156e3def4022c7ea6c17f8b06 = $(`&lt;div id=&quot;html_ec2f460156e3def4022c7ea6c17f8b06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 127, 0.030916935476, NW&lt;/div&gt;`)[0];
#                 popup_814891390dfa3e7554ae3457f0cdfd98.setContent(html_ec2f460156e3def4022c7ea6c17f8b06);
#
#
#
#         poly_line_8a718364d8a49c43049d2b06a49d9aaa.bindPopup(popup_814891390dfa3e7554ae3457f0cdfd98)
#         ;
#
#
#
#
#             var poly_line_05b317a3515a3f53877a3195f51f0967 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_edec2398bea4442d2e4fd5db13a52be1);
#
#
#         var popup_8db63763cccc494558c2149e5677e370 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8ac39c3029766fcfca14f2a4e9b41f7 = $(`&lt;div id=&quot;html_e8ac39c3029766fcfca14f2a4e9b41f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 2.114280692826, SW&lt;/div&gt;`)[0];
#                 popup_8db63763cccc494558c2149e5677e370.setContent(html_e8ac39c3029766fcfca14f2a4e9b41f7);
#
#
#
#         poly_line_05b317a3515a3f53877a3195f51f0967.bindPopup(popup_8db63763cccc494558c2149e5677e370)
#         ;
#
#
#
#
#             var poly_line_ae26b9c6d6c08668047e20f541c2ca65 = L.polyline(
#                 [[42.2768179, -84.362715], [42.2772818, -84.3209965]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_edec2398bea4442d2e4fd5db13a52be1);
#
#
#         var popup_0af102ade55550a49d888aaf1dffdf1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b28cdcfc93b4fa878e3d810d9d2f0c6 = $(`&lt;div id=&quot;html_9b28cdcfc93b4fa878e3d810d9d2f0c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 2.131730033248, NE&lt;/div&gt;`)[0];
#                 popup_0af102ade55550a49d888aaf1dffdf1c.setContent(html_9b28cdcfc93b4fa878e3d810d9d2f0c6);
#
#
#
#         poly_line_ae26b9c6d6c08668047e20f541c2ca65.bindPopup(popup_0af102ade55550a49d888aaf1dffdf1c)
#         ;
#
#
#
#
#             var poly_line_f1c5620426b221676e48bc112ee0bd38 = L.polyline(
#                 [[42.2

# %%
m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fd7b75c523fa09d2f197d5a19072ac3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fd7b75c523fa09d2f197d5a19072ac3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fd7b75c523fa09d2f197d5a19072ac3 = L.map(
#                 &quot;map_7fd7b75c523fa09d2f197d5a19072ac3&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ae29773c29adc87218671247dd091fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fd7b75c523fa09d2f197d5a19072ac3);
#
#
#             var poly_line_0f9847a6844cf676d26b47bcad06629b = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_7fd7b75c523fa09d2f197d5a19072ac3);
#
#
#         var popup_21deff41b1269e3390bd9ca40f773212 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81e9c5dd91ec8f767c62a9fdad53ea3c = $(`&lt;div id=&quot;html_81e9c5dd91ec8f767c62a9fdad53ea3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94&lt;/div&gt;`)[0];
#                 popup_21deff41b1269e3390bd9ca40f773212.setContent(html_81e9c5dd91ec8f767c62a9fdad53ea3c);
#
#
#
#         poly_line_0f9847a6844cf676d26b47bcad06629b.bindPopup(popup_21deff41b1269e3390bd9ca40f773212)
#         ;
#
#
#
#
#             var poly_line_2e503f74e3f8ad1911a389fcbaf9897c = L.polyline(
#                 [[42.2823716, -84.9244721], [42.2823737, -84.9238378]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_7fd7b75c523fa09d2f197d5a19072ac3);
#
#
#         var popup_5dc7b288c8e94da06d86a8a48db4a463 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be0ae3864593ea476d8ea6f63fc8cf7c = $(`&lt;div id=&quot;html_be0ae3864593ea476d8ea6f63fc8cf7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94&lt;/div&gt;`)[0];
#                 popup_5dc7b288c8e94da06d86a8a48db4a463.setContent(html_be0ae3864593ea476d8ea6f63fc8cf7c);
#
#
#
#         poly_line_2e503f74e3f8ad1911a389fcbaf9897c.bindPopup(popup_5dc7b288c8e94da06d86a8a48db4a463)
#         ;
#
#
#
#
#             var marker_d11eec8a09377a70792dc2cd80b92690 = L.marker(
#                 [42.293894, -84.275253],
#                 {}
#             ).addTo(map_7fd7b75c523fa09d2f197d5a19072ac3);
#
#
#         var popup_db67bb29109ae8ea2f0ce3b38f87938e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07d259720972a9ac0c122210d37aa40d = $(`&lt;div id=&quot;html_07d259720972a9ac0c122210d37aa40d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.293894 lon: -84.275253&lt;/div&gt;`)[0];
#                 popup_db67bb29109ae8ea2f0ce3b38f87938e.setContent(html_07d259720972a9ac0c122210d37aa40d);
#
#
#
#         marker_d11eec8a09377a70792dc2cd80b92690.bindPopup(popup_db67bb29109ae8ea2f0ce3b38f87938e)
#         ;
#
#
#
#
#             var marker_3a6044a261820d20d9ea62be5a607d15 = L.marker(
#                 [42.271693, -84.847918],
#                 {}
#             ).addTo(map_7fd7b75c523fa09d2f197d5a19072ac3);
#
#
#         var popup_47c8a7dad0575df651b28f39f3093559 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59da0cbef38572683cdcaf83804a2d21 = $(`&lt;div id=&quot;html_59da0cbef38572683cdcaf83804a2d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.271693 lon: -84.847918&lt;/div&gt;`)[0];
#                 popup_47c8a7dad0575df651b28f39f3093559.setContent(html_59da0cbef38572683cdcaf83804a2d21);

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# {'start': {'lat': 42.293894, 'lon': -84.275253}, 'end': {'lat': 42.271693, 'lon': -84.847918}, 'startWay': {'id': 60733805, 'length_mi': 3.365964221516, 'time_s': 173.10673139225145, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '70 mph', 'oneway': 'yes', 'ref': 'I 94'}, 'startNode': {'id': 184675113, 'lat': 42.2918595, 'long': -84.2601946}, 'endNode': {'id': 184675297, 'lat': 42.2773942, 'long': -84.3216809}}, 'endWay': {'id': 130946031, 'length_mi': 0.032400148053000004, 'time_s': 1.66629332844, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '70 mph', 'oneway': 'yes', 'ref': 'I 94'}, 'startNode': {'id': 1441593800, 'lat': 42.2823716, 'long': -84.9244721}, 'endNode': {'id': 1441593818, 'lat': 42.2823737, 'long': -84.9238378}}}
# Expected Distance 22.24 miles
# Expected Time: 19 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ee9e593736061ba98c0d8124df893bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ee9e593736061ba98c0d8124df893bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ee9e593736061ba98c0d8124df893bd = L.map(
#                 &quot;map_8ee9e593736061ba98c0d8124df893bd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36936c82e046eca645c706af966b5058 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8ee9e593736061ba98c0d8124df893bd);
#
#
#             var poly_line_e81fe5f8c4efb11b413f559ce5032f0c = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_8ee9e593736061ba98c0d8124df893bd);
#
#
#         var popup_f0bf1f8c90721d3af288d3ff62278c3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ed7798194235f118c033060a870550e = $(`&lt;div id=&quot;html_4ed7798194235f118c033060a870550e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, SW&lt;/div&gt;`)[0];
#                 popup_f0bf1f8c90721d3af288d3ff62278c3e.setContent(html_4ed7798194235f118c033060a870550e);
#
#
#
#         poly_line_e81fe5f8c4efb11b413f559ce5032f0c.bindPopup(popup_f0bf1f8c90721d3af288d3ff62278c3e)
#         ;
#
#
#
#
#             var poly_line_a01e755bd0372c4e96ed35dc528b2d56 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_8ee9e593736061ba98c0d8124df893bd);
#
#
#         var popup_5882870e38cade86a19d57f4d915c735 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8b489869fdf359283678487dd45b29c = $(`&lt;div id=&quot;html_a8b489869fdf359283678487dd45b29c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, SW&lt;/div&gt;`)[0];
#                 popup_5882870e38cade86a19d57f4d915c735.setContent(html_a8b489869fdf359283678487dd45b29c);
#
#
#
#         poly_line_a01e755bd0372c4e96ed35dc528b2d56.bindPopup(popup_5882870e38cade86a19d57f4d915c735)
#         ;
#
#
#
#
#             var poly_line_9e936de10fbea7dc9656b501690fabcf = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_8ee9e593736061ba98c0d8124df893bd);
#
#
#         var popup_907bd69076441e7fff9da3108b623812 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a437ce42b082d78f5ab0ff8a2b8670c3 = $(`&lt;div id=&quot;html_a437ce42b082d78f5ab0ff8a2b8670c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, SW&lt;/div&gt;`)[0];
#                 popup_907bd69076441e7fff9da3108b623812.setContent(html_a437ce42b082d78f5ab0ff8a2b8670c3);
#
#
#
#         poly_line_9e936de10fbea7dc9656b501690fabcf.bindPopup(popup_907bd69076441e7fff9da3108b623812)
#         ;
#
#
#
#
#             var poly_line_0e4e07ceec3b17eff38604e8feec16b3 = L.polyline(
#                 [[42.2715138, -84.4068168], [42.2716489, -84.409483]],

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# {'start': {'lat': 35.128556, 'lon': -111.200147}, 'end': {'lat': 35.054526, 'lon': -108.80271}, 'startWay': {'id': 849020694, 'length_mi': 0.405516035165, 'time_s': 19.46476968792, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '75 mph', 'name': 'Purple Heart Trail', 'oneway': 'yes', 'ref': 'I 40;US 180'}, 'startNode': {'id': 1579927147, 'lat': 35.133652, 'long': -111.1966896}, 'endNode': {'id': 268683087, 'lat': 35.1312375, 'long': -111.1901426}}, 'endWay': {'id': 47989616, 'length_mi': 0.021373298287, 'time_s': 1.0259183177759998, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '75 mph', 'name': 'Purple Heart Trail', 'oneway': 'yes', 'ref': 'I 40', 'surface': 'asphalt'}, 'startNode': {'id': 610343867, 'lat': 35.3103391, 'long': -109.1069681}, 'endNode': {'id': 610343865, 'lat': 35.310488, 'long': -109.1066355}}}
# Expected Distance 79.35 miles
# Expected Time: 1 hrs 3 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bcba6e3af38dc7239f5f0aae7187024 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bcba6e3af38dc7239f5f0aae7187024&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bcba6e3af38dc7239f5f0aae7187024 = L.map(
#                 &quot;map_2bcba6e3af38dc7239f5f0aae7187024&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_219476a7a827b57194820f266b211ae2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2bcba6e3af38dc7239f5f0aae7187024);
#
#
#             var poly_line_47e5e52402c5291a19db66d9cc67884e = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_2bcba6e3af38dc7239f5f0aae7187024);
#
#
#         var popup_6c44ddcbedd40cf6759f2847d835e41f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2156a71b7a6808efb51bf941f7cc1567 = $(`&lt;div id=&quot;html_2156a71b7a6808efb51bf941f7cc1567&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, SE&lt;/div&gt;`)[0];
#                 popup_6c44ddcbedd40cf6759f2847d835e41f.setContent(html_2156a71b7a6808efb51bf941f7cc1567);
#
#
#
#         poly_line_47e5e52402c5291a19db66d9cc67884e.bindPopup(popup_6c44ddcbedd40cf6759f2847d835e41f)
#         ;
#
#
#
#
#             var poly_line_5850bba160fe18137f06c4f5ab7c5856 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_2bcba6e3af38dc7239f5f0aae7187024);
#
#
#         var popup_a74a4399449dd306ded29df50eb9caf6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f1bba6cedcb0c97b7fbcc55756552e4 = $(`&lt;div id=&quot;html_6f1bba6cedcb0c97b7fbcc55756552e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, SE&lt;/div&gt;`)[0];
#                 popup_a74a4399449dd306ded29df50eb9caf6.setContent(html_6f1bba6cedcb0c97b7fbcc55756552e4);
#
#
#
#         poly_line_5850bba160fe18137f06c4f5ab7c5856.bindPopup(popup_a74a4399449dd306ded29df50eb9caf6)
#         ;
#
#
#
#
#             var poly_line_7da607644d2fa159ae953a045f20161f = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_2bcba6e3af38dc7239f5f0aae7187024);
#
#
#         var popup_beed5e30dda2351d3fc49975c75bc02d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_66aaf69928bbe8199baacaedb6a49a8d = $(`&lt;div id=&quot;html_66aaf69928bbe8199baacaedb6a49a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, SE&lt;/div&gt;`)[0];
#                 popup_beed5e30dda2351d3fc49975c75bc02d.setContent(html_66aaf69928bbe8199baacaedb6a49a8d);
#
#
#
#         poly_line_7da607644d2fa159ae953a045f20161f.bindPopup(popup_beed5e30dda2351d3fc49975c75bc02d)
#         ;
#
#
#
#
#             var poly_line_bd19aca9ceb36f1e78d5905cb7c7e7c0 = L.polyline(
#                 [[35.1289647, -111.1839182], [35.12

# %%
m = mapper.mapEndWays([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb0ff20503597535314c0b98234db1a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb0ff20503597535314c0b98234db1a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb0ff20503597535314c0b98234db1a0 = L.map(
#                 &quot;map_bb0ff20503597535314c0b98234db1a0&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cc6f7c3c9e4ce533a6cd16a0b21e246 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb0ff20503597535314c0b98234db1a0);
#
#
#             var poly_line_692dbb99c35a5c7fb72f4c8fa67dc3bb = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_bb0ff20503597535314c0b98234db1a0);
#
#
#         var popup_157c846cfd702306a1cc20ade9e068a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d661de709754c04f25d9a9c5988079b = $(`&lt;div id=&quot;html_8d661de709754c04f25d9a9c5988079b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40&lt;/div&gt;`)[0];
#                 popup_157c846cfd702306a1cc20ade9e068a5.setContent(html_8d661de709754c04f25d9a9c5988079b);
#
#
#
#         poly_line_692dbb99c35a5c7fb72f4c8fa67dc3bb.bindPopup(popup_157c846cfd702306a1cc20ade9e068a5)
#         ;
#
#
#
#
#             var poly_line_9dc90d8d06d412e77ab31a9ced61f242 = L.polyline(
#                 [[35.3103391, -109.1069681], [35.310488, -109.1066355]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_bb0ff20503597535314c0b98234db1a0);
#
#
#         var popup_4bd803590a9f814b6cceab22de6fae90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_415d187eb49e8103dbf8ac091660ada7 = $(`&lt;div id=&quot;html_415d187eb49e8103dbf8ac091660ada7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40&lt;/div&gt;`)[0];
#                 popup_4bd803590a9f814b6cceab22de6fae90.setContent(html_415d187eb49e8103dbf8ac091660ada7);
#
#
#
#         poly_line_9dc90d8d06d412e77ab31a9ced61f242.bindPopup(popup_4bd803590a9f814b6cceab22de6fae90)
#         ;
#
#
#
#
#             var marker_96f14bf48967c4544be464983e765aba = L.marker(
#                 [34.928556, -115.200147],
#                 {}
#             ).addTo(map_bb0ff20503597535314c0b98234db1a0);
#
#
#         var popup_0955c5cf31f8e92c292a29c8bbf2a4ae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b10b2ff1ab9eab61a30ef01f2b7fc5bd = $(`&lt;div id=&quot;html_b10b2ff1ab9eab61a30ef01f2b7fc5bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 34.928556 lon: -115.200147&lt;/div&gt;`)[0];
#                 popup_0955c5cf31f8e92c292a29c8bbf2a4ae.setContent(html_b10b2ff1ab9eab61a30ef01f2b7fc5bd);
#
#
#
#         marker_96f14bf48967c4544be464983e765aba.bindPopup(popup_0955c5cf31f8e92c292a29c8bbf2a4ae)
#         ;
#
#
#
#
#             var marker_b4e8314266ee61820b0a72728436854e = L.marker(
#                 [35.054526, -108.80271],
#                 {}
#             ).addTo(map_bb0ff20503597535314c0b98234db1a0);
#
#
#         var popup_6ade0b7e022694ab2ed9c49cf9aa633a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f1d9ecbe6a85c72a9b4e38da7cb097a = $(`&lt;div id=&quot;html_3f1d9ecbe6a85c72a9b4e38da7cb097a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 35.054526 lon: -108.80271&lt;/div&gt;`)[0];
#                 popup_6ade0b7e022694ab2ed9c49cf9aa633a.setContent(html_3f1d9ecbe6a85c72a9b4e38da7cb097a);

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# {'start': {'lat': 34.928556, 'lon': -115.200147}, 'end': {'lat': 35.054526, 'lon': -108.80271}, 'startWay': {'id': 26786185, 'length_mi': 8.008241254049, 'time_s': 411.8524073510914, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '70 mph', 'name': 'Needles Freeway', 'oneway': 'yes', 'ref': 'I 40'}, 'startNode': {'id': 293816351, 'lat': 34.8127386, 'long': -115.1836298}, 'endNode': {'id': 1700023437, 'lat': 34.8301903, 'long': -115.0440819}}, 'endWay': {'id': 47989616, 'length_mi': 0.021373298287, 'time_s': 1.0259183177759998, 'tags': {'highway': 'motorway', 'lanes': '2', 'maxspeed': '75 mph', 'name': 'Purple Heart Trail', 'oneway': 'yes', 'ref': 'I 40', 'surface': 'asphalt'}, 'startNode': {'id': 610343867, 'lat': 35.3103391, 'long': -109.1069681}, 'endNode': {'id': 610343865, 'lat': 35.310488, 'long': -109.1066355}}}
# Expected Distance 154.66 miles
# Expected Time: 2 hrs 5 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcfe5e523f966ec19e647e8b46d9954e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcfe5e523f966ec19e647e8b46d9954e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcfe5e523f966ec19e647e8b46d9954e = L.map(
#                 &quot;map_dcfe5e523f966ec19e647e8b46d9954e&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e76f5760151ddeb04d745ee62a3eee0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dcfe5e523f966ec19e647e8b46d9954e);
#
#
#             var poly_line_e98fc9623fd32047702cf87db995431b = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_dcfe5e523f966ec19e647e8b46d9954e);
#
#
#         var popup_1d6c260ac52fe94b53f3b071d6fbe6ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f58aed072d000dbab52e789954b727f = $(`&lt;div id=&quot;html_0f58aed072d000dbab52e789954b727f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, NE&lt;/div&gt;`)[0];
#                 popup_1d6c260ac52fe94b53f3b071d6fbe6ed.setContent(html_0f58aed072d000dbab52e789954b727f);
#
#
#
#         poly_line_e98fc9623fd32047702cf87db995431b.bindPopup(popup_1d6c260ac52fe94b53f3b071d6fbe6ed)
#         ;
#
#
#
#
#             var poly_line_f5293369f4aa92c870cfd9a5ba8a3876 = L.polyline(
#                 [[34.8301903, -115.0440819], [34.8389344, -114.9920261]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_dcfe5e523f966ec19e647e8b46d9954e);
#
#
#         var popup_9b23123ca6c5a4782d653ff4ea64a098 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8de0d870103fe84e53366968d2cf09e6 = $(`&lt;div id=&quot;html_8de0d870103fe84e53366968d2cf09e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, NE&lt;/div&gt;`)[0];
#                 popup_9b23123ca6c5a4782d653ff4ea64a098.setContent(html_8de0d870103fe84e53366968d2cf09e6);
#
#
#
#         poly_line_f5293369f4aa92c870cfd9a5ba8a3876.bindPopup(popup_9b23123ca6c5a4782d653ff4ea64a098)
#         ;
#
#
#
#
#             var poly_line_208d2282a034ffa56c881e31369a1b7d = L.polyline(
#                 [[34.8389344, -114.9920261], [34.8390215, -114.9916998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_dcfe5e523f966ec19e647e8b46d9954e);
#
#
#         var popup_5417273f0d0e5c0f4f374d9b6500b3e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8b2fe28389d3bd22029590006bf2a88 = $(`&lt;div id=&quot;html_b8b2fe28389d3bd22029590006bf2a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, NE&lt;/div&gt;`)[0];
#                 popup_5417273f0d0e5c0f4f374d9b6500b3e3.setContent(html_b8b2fe28389d3bd22029590006bf2a88);
#
#
#
#         poly_line_208d2282a034ffa56c881e31369a1b7d.bindPopup(popup_5417273f0d0e5c0f4f374d9b6500b3e3)
#         ;
#
#
#
#
#             var poly_line_7c151147e361da2c8efec16d2097c2a7 = L.polyline(
#                 [[34.8390215, -114.9916998], [34.8428602, -114.9779585]
