# %%
import folium
from mapping import mapper

# %%
mapper = mapper()

# %%
m = mapper.mapHighways([42.228708, -84.935065], [42.344618, -84.294575])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea0fd53b47125188e811375afb85caf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea0fd53b47125188e811375afb85caf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea0fd53b47125188e811375afb85caf4 = L.map(
#                 &quot;map_ea0fd53b47125188e811375afb85caf4&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e83f33d27c5d88cc5b366fdd5863ee49 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea0fd53b47125188e811375afb85caf4);
#
#
#             var poly_line_071a6a72f01880671178a70cfab2247c = L.polyline(
#                 [[42.2767394, -84.3586325], [42.2771861, -84.358675]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ea0fd53b47125188e811375afb85caf4);
#
#
#         var popup_4fc08a2204e96db0108f2fef8c3e1ab4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5572859b64b6aca7db0f4d51e90cfafe = $(`&lt;div id=&quot;html_5572859b64b6aca7db0f4d51e90cfafe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 127, 41007437, NW, 0.030916935476&lt;/div&gt;`)[0];
#                 popup_4fc08a2204e96db0108f2fef8c3e1ab4.setContent(html_5572859b64b6aca7db0f4d51e90cfafe);
#
#
#
#         poly_line_071a6a72f01880671178a70cfab2247c.bindPopup(popup_4fc08a2204e96db0108f2fef8c3e1ab4)
#         ;
#
#
#
#
#             var poly_line_64fc4e1eb887a2ce06051bf9a56a1b18 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ea0fd53b47125188e811375afb85caf4);
#
#
#         var popup_a8bf0d3eb3bad241a24046502b0b90af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cddcedeee5061084cf9c4c18eda868cc = $(`&lt;div id=&quot;html_cddcedeee5061084cf9c4c18eda868cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_a8bf0d3eb3bad241a24046502b0b90af.setContent(html_cddcedeee5061084cf9c4c18eda868cc);
#
#
#
#         poly_line_64fc4e1eb887a2ce06051bf9a56a1b18.bindPopup(popup_a8bf0d3eb3bad241a24046502b0b90af)
#         ;
#
#
#
#
#             var poly_line_1d493b3a57d1e8b2e00bbd2ac701fbae = L.polyline(
#                 [[42.2768179, -84.362715], [42.2772818, -84.3209965]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ea0fd53b47125188e811375afb85caf4);
#
#
#         var popup_b691eec9b590d347d01e1648a74a09e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5eeded2639c5b82f7eff14200e58058d = $(`&lt;div id=&quot;html_5eeded2639c5b82f7eff14200e58058d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 41007439, NE, 2.131730033248&lt;/div&gt;`)[0];
#                 popup_b691eec9b590d347d01e1648a74a09e6.setContent(html_5eeded2639c5b82f7eff14200e58058d);
#
#
#
#         poly_line_1d493b3a57d1e8b2e00bbd2ac701fbae.bindPopup(popup_b691eec9b590d347d01e1648a74a09e6)
#         ;
#
#
#
#
#             var poly_line_c6c9f273e6e7736e9a66ee409d6d9271 = L.po

# %%
m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d7c6745ca83c135e39f6084146ba93b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d7c6745ca83c135e39f6084146ba93b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d7c6745ca83c135e39f6084146ba93b = L.map(
#                 &quot;map_2d7c6745ca83c135e39f6084146ba93b&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7d917b00036b35e7f85aa1ad581ae8d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2d7c6745ca83c135e39f6084146ba93b);
#
#
#             var poly_line_f1a7223c97d34b70cf63ed16873e4dba = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_2d7c6745ca83c135e39f6084146ba93b);
#
#
#         var popup_174ba216823ac51498459613277dd1c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_500bb7d7606a4f12f67f9b664a198c32 = $(`&lt;div id=&quot;html_500bb7d7606a4f12f67f9b664a198c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_174ba216823ac51498459613277dd1c1.setContent(html_500bb7d7606a4f12f67f9b664a198c32);
#
#
#
#         poly_line_f1a7223c97d34b70cf63ed16873e4dba.bindPopup(popup_174ba216823ac51498459613277dd1c1)
#         ;
#
#
#
#
#             var poly_line_b5cbb09618e80a2cedb8ec8f20c8f344 = L.polyline(
#                 [[42.263883, -84.717211], [42.2826357, -84.9237923]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_2d7c6745ca83c135e39f6084146ba93b);
#
#
#         var popup_00fd76399923a33e89e95278a40bd88b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adf54d0be92ff176eb58792ceb895457 = $(`&lt;div id=&quot;html_adf54d0be92ff176eb58792ceb895457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 17739272, NW, 11.118410646963&lt;/div&gt;`)[0];
#                 popup_00fd76399923a33e89e95278a40bd88b.setContent(html_adf54d0be92ff176eb58792ceb895457);
#
#
#
#         poly_line_b5cbb09618e80a2cedb8ec8f20c8f344.bindPopup(popup_00fd76399923a33e89e95278a40bd88b)
#         ;
#
#
#
#
#             var marker_bd136ecc693ac736aaa9a9fe0ec3b6e5 = L.marker(
#                 [42.293894, -84.275253],
#                 {}
#             ).addTo(map_2d7c6745ca83c135e39f6084146ba93b);
#
#
#         var popup_4f215f27dc6c4e64ebefcecb20cf4e5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc76bd52c50c90838be3f1ea50c9714b = $(`&lt;div id=&quot;html_fc76bd52c50c90838be3f1ea50c9714b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.293894 lon: -84.275253&lt;/div&gt;`)[0];
#                 popup_4f215f27dc6c4e64ebefcecb20cf4e5e.setContent(html_fc76bd52c50c90838be3f1ea50c9714b);
#
#
#
#         marker_bd136ecc693ac736aaa9a9fe0ec3b6e5.bindPopup(popup_4f215f27dc6c4e64ebefcecb20cf4e5e)
#         ;
#
#
#
#
#             var marker_2314b4299266ef842aab1fd3d4db2baa = L.marker(
#                 [42.271693, -84.847918],
#                 {}
#             ).addTo(map_2d7c6745ca83c135e39f6084146ba93b);
#
#
#         var popup_5f8842ef904bf5d3493a3a5a3e744c78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1e316263500d82142b25c9e198521b3 = $(`&lt;div id=&quot;html_a1e316263500d82142b25c9e198521b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.271693 lon: -84.847918&lt;/div&gt;`)[0];
#                 popup_5f8842ef904bf5d3493a3a5a3e744c7

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Expected Distance 31.52 miles
# Expected Time: 27 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9ce7dbcd44a9a896da5e11f38ea5bb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9ce7dbcd44a9a896da5e11f38ea5bb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9ce7dbcd44a9a896da5e11f38ea5bb3 = L.map(
#                 &quot;map_f9ce7dbcd44a9a896da5e11f38ea5bb3&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7321f6f9fee7306aa19099ecbc33cd2c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9ce7dbcd44a9a896da5e11f38ea5bb3);
#
#
#             var poly_line_7f09ee92e5485988e480788e68fe684d = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f9ce7dbcd44a9a896da5e11f38ea5bb3);
#
#
#         var popup_dd92ff549126d07381ef9f9cb462a25e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3b675e99db34e2b651508561a08e058 = $(`&lt;div id=&quot;html_a3b675e99db34e2b651508561a08e058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_dd92ff549126d07381ef9f9cb462a25e.setContent(html_a3b675e99db34e2b651508561a08e058);
#
#
#
#         poly_line_7f09ee92e5485988e480788e68fe684d.bindPopup(popup_dd92ff549126d07381ef9f9cb462a25e)
#         ;
#
#
#
#
#             var poly_line_44fc3d5c63ccadc31300e364b64fe49a = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f9ce7dbcd44a9a896da5e11f38ea5bb3);
#
#
#         var popup_226eb4d55874b296243fc5e118da6c46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e98c0085ecbc9705981be94f787404e = $(`&lt;div id=&quot;html_0e98c0085ecbc9705981be94f787404e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_226eb4d55874b296243fc5e118da6c46.setContent(html_0e98c0085ecbc9705981be94f787404e);
#
#
#
#         poly_line_44fc3d5c63ccadc31300e364b64fe49a.bindPopup(popup_226eb4d55874b296243fc5e118da6c46)
#         ;
#
#
#
#
#             var poly_line_0e9e0fb66893f4498d24bdd2924f91ae = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f9ce7dbcd44a9a896da5e11f38ea5bb3);
#
#
#         var popup_a2ba40aed2857f8b998bc9a9388a1b9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c63268b307ef0bce861824f3b2930a73 = $(`&lt;div id=&quot;html_c63268b307ef0bce861824f3b2930a73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_a2ba40aed2857f8b998bc9a9388a1b9b.setContent(html_c63268b307ef0bce861824f3b2930a73);
#
#
#
#         poly_line_0e9e0fb66893f4498d24bdd2924f91ae.bindPopup(popup_a2ba40aed2857f8b998bc9a9388a1b9b)
#         ;
#
#
#
#
#             var poly_line_15084659a21d8bde53a309a497a76a32 =

# %%
m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e612836d71c94e84b6db58b4c8fc97b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e612836d71c94e84b6db58b4c8fc97b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e612836d71c94e84b6db58b4c8fc97b = L.map(
#                 &quot;map_6e612836d71c94e84b6db58b4c8fc97b&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_147b3f83ece0177c507288cf22cf6002 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e612836d71c94e84b6db58b4c8fc97b);
#
#
#             var poly_line_e8db09e707aa368f929a8a438e338b8b = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6e612836d71c94e84b6db58b4c8fc97b);
#
#
#         var popup_e9d8abaa5910a7d6a20b4089375b2797 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1551e6ef9fd01e6b4248da9aa47e7c3f = $(`&lt;div id=&quot;html_1551e6ef9fd01e6b4248da9aa47e7c3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_e9d8abaa5910a7d6a20b4089375b2797.setContent(html_1551e6ef9fd01e6b4248da9aa47e7c3f);
#
#
#
#         poly_line_e8db09e707aa368f929a8a438e338b8b.bindPopup(popup_e9d8abaa5910a7d6a20b4089375b2797)
#         ;
#
#
#
#
#             var poly_line_f07c762fb210b3639e0b0b731d774a03 = L.polyline(
#                 [[42.263883, -84.717211], [42.2826357, -84.9237923]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6e612836d71c94e84b6db58b4c8fc97b);
#
#
#         var popup_229d48a4ef0064b8b283dd6a414d9562 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1de27ff8f300822e552c5733e9f186d = $(`&lt;div id=&quot;html_f1de27ff8f300822e552c5733e9f186d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 17739272, NW, 11.118410646963&lt;/div&gt;`)[0];
#                 popup_229d48a4ef0064b8b283dd6a414d9562.setContent(html_f1de27ff8f300822e552c5733e9f186d);
#
#
#
#         poly_line_f07c762fb210b3639e0b0b731d774a03.bindPopup(popup_229d48a4ef0064b8b283dd6a414d9562)
#         ;
#
#
#
#
#             var marker_b00bd9ced267014dd452db7036342979 = L.marker(
#                 [42.293894, -84.275253],
#                 {}
#             ).addTo(map_6e612836d71c94e84b6db58b4c8fc97b);
#
#
#         var popup_ab14b25313c30488596d3519a862956f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1105b6a421ed7e60c018a3f5845fd397 = $(`&lt;div id=&quot;html_1105b6a421ed7e60c018a3f5845fd397&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.293894 lon: -84.275253&lt;/div&gt;`)[0];
#                 popup_ab14b25313c30488596d3519a862956f.setContent(html_1105b6a421ed7e60c018a3f5845fd397);
#
#
#
#         marker_b00bd9ced267014dd452db7036342979.bindPopup(popup_ab14b25313c30488596d3519a862956f)
#         ;
#
#
#
#
#             var marker_e199fbe8c82f88b903c1b19de4e9bf99 = L.marker(
#                 [42.271693, -84.847918],
#                 {}
#             ).addTo(map_6e612836d71c94e84b6db58b4c8fc97b);
#
#
#         var popup_cfa8f1d8aaf16ca1e4259b718067a194 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_35d0d4193a9e41ba38340b4ceae6b3fd = $(`&lt;div id=&quot;html_35d0d4193a9e41ba38340b4ceae6b3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 42.271693 lon: -84.847918&lt;/div&gt;`)[0];
#                 popup_cfa8f1d8aaf16ca1e4259b718067a19

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 129.59 miles
# Expected Time: 1 hrs 43 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_469fc58061a7ff99eb717dcab8637039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_469fc58061a7ff99eb717dcab8637039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_469fc58061a7ff99eb717dcab8637039 = L.map(
#                 &quot;map_469fc58061a7ff99eb717dcab8637039&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_218a238b229423ebd522ee0ae590973e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_469fc58061a7ff99eb717dcab8637039);
#
#
#             var poly_line_aa17e61fcacaa09ae1d759681c1a662e = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_469fc58061a7ff99eb717dcab8637039);
#
#
#         var popup_1c79e624b5403201ea8f6b83b23c0a9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b2700c33f1dbfcdb871d0231db1762d = $(`&lt;div id=&quot;html_8b2700c33f1dbfcdb871d0231db1762d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 849020694, SE, 0.405516035165&lt;/div&gt;`)[0];
#                 popup_1c79e624b5403201ea8f6b83b23c0a9b.setContent(html_8b2700c33f1dbfcdb871d0231db1762d);
#
#
#
#         poly_line_aa17e61fcacaa09ae1d759681c1a662e.bindPopup(popup_1c79e624b5403201ea8f6b83b23c0a9b)
#         ;
#
#
#
#
#             var poly_line_e2317793d0388fd059e00a9a9c63e993 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_469fc58061a7ff99eb717dcab8637039);
#
#
#         var popup_237830cdb69e9d096288830cbf90cd68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df6eb573f3f81a6c5260ab6ac0c8330c = $(`&lt;div id=&quot;html_df6eb573f3f81a6c5260ab6ac0c8330c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447120, SE, 0.015121684655999999&lt;/div&gt;`)[0];
#                 popup_237830cdb69e9d096288830cbf90cd68.setContent(html_df6eb573f3f81a6c5260ab6ac0c8330c);
#
#
#
#         poly_line_e2317793d0388fd059e00a9a9c63e993.bindPopup(popup_237830cdb69e9d096288830cbf90cd68)
#         ;
#
#
#
#
#             var poly_line_3674fcb276ee4a840f052fca49e5c244 = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_469fc58061a7ff99eb717dcab8637039);
#
#
#         var popup_a8d37770b66b895408338bca3350e976 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05bc12efafd296b82f274f1a8a6f5db5 = $(`&lt;div id=&quot;html_05bc12efafd296b82f274f1a8a6f5db5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447112, SE, 0.36979217363300004&lt;/div&gt;`)[0];
#                 popup_a8d37770b66b895408338bca3350e976.setContent(html_05bc12efafd296b82f274f1a8a6f5db5);
#
#
#
#         poly_line_3674fcb276ee4a840f052fca49e5c244.bindPopup(popup_a8d37770b66b895408338bca3350e976)
#         ;
#
#
#
#
#             var poly_line_fed55b

# %%
m = mapper.mapEndWays([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef89a8c621e9763fd17e769ab9547323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef89a8c621e9763fd17e769ab9547323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef89a8c621e9763fd17e769ab9547323 = L.map(
#                 &quot;map_ef89a8c621e9763fd17e769ab9547323&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bca9b7741b70de9ca50f8b9d65aac5ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef89a8c621e9763fd17e769ab9547323);
#
#
#             var poly_line_ffba80b4b14a4c78c310ac351a8358e6 = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ef89a8c621e9763fd17e769ab9547323);
#
#
#         var popup_34cdd23fa1b8eb20b8aace03e31bf0ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0a75547d75128b0db0b643d09ec1ecf = $(`&lt;div id=&quot;html_a0a75547d75128b0db0b643d09ec1ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 26786185, NE, 8.008241254049&lt;/div&gt;`)[0];
#                 popup_34cdd23fa1b8eb20b8aace03e31bf0ab.setContent(html_a0a75547d75128b0db0b643d09ec1ecf);
#
#
#
#         poly_line_ffba80b4b14a4c78c310ac351a8358e6.bindPopup(popup_34cdd23fa1b8eb20b8aace03e31bf0ab)
#         ;
#
#
#
#
#             var poly_line_908631197f5537aa73b7b3b27b6ac270 = L.polyline(
#                 [[35.3103391, -109.1069681], [35.310488, -109.1066355]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ef89a8c621e9763fd17e769ab9547323);
#
#
#         var popup_dcb8596a9cea63fec7b949f6d6c10662 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c71b80f88deaf21e03f2f478df824ad = $(`&lt;div id=&quot;html_4c71b80f88deaf21e03f2f478df824ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 47989616, NE, 0.021373298287&lt;/div&gt;`)[0];
#                 popup_dcb8596a9cea63fec7b949f6d6c10662.setContent(html_4c71b80f88deaf21e03f2f478df824ad);
#
#
#
#         poly_line_908631197f5537aa73b7b3b27b6ac270.bindPopup(popup_dcb8596a9cea63fec7b949f6d6c10662)
#         ;
#
#
#
#
#             var marker_f62989e338017773f13568044c45bebe = L.marker(
#                 [34.928556, -115.200147],
#                 {}
#             ).addTo(map_ef89a8c621e9763fd17e769ab9547323);
#
#
#         var popup_26d98a8745caa1de735a543ca43f7570 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_464bcdde8ea178029b2e057f7f03b2f7 = $(`&lt;div id=&quot;html_464bcdde8ea178029b2e057f7f03b2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 34.928556 lon: -115.200147&lt;/div&gt;`)[0];
#                 popup_26d98a8745caa1de735a543ca43f7570.setContent(html_464bcdde8ea178029b2e057f7f03b2f7);
#
#
#
#         marker_f62989e338017773f13568044c45bebe.bindPopup(popup_26d98a8745caa1de735a543ca43f7570)
#         ;
#
#
#
#
#             var marker_103be3de6a6cc283ca1e86770377695a = L.marker(
#                 [35.054526, -108.80271],
#                 {}
#             ).addTo(map_ef89a8c621e9763fd17e769ab9547323);
#
#
#         var popup_57df7996638636b2e77eab3c48307191 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9b415e2cb8b416828a48c64cfee8a60 = $(`&lt;div id=&quot;html_b9b415e2cb8b416828a48c64cfee8a60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lat: 35.054526 lon: -108.80271&lt;/div&gt;`)[0];
#                 popup_57df7996638636b2e77eab3c4

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 392.30 miles
# Expected Time: 5 hrs 17 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6c4cc67bc4bf224e95d94f52b32d77c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6c4cc67bc4bf224e95d94f52b32d77c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6c4cc67bc4bf224e95d94f52b32d77c = L.map(
#                 &quot;map_e6c4cc67bc4bf224e95d94f52b32d77c&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f4ad2d34c87f3611713e94de57f010a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6c4cc67bc4bf224e95d94f52b32d77c);
#
#
#             var poly_line_a0cc1f042668ff49f979339adee96dc7 = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e6c4cc67bc4bf224e95d94f52b32d77c);
#
#
#         var popup_4efce78327a118ff3ecd9c25da50839a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ea106f1957290e99b6b53cacc8fc53a = $(`&lt;div id=&quot;html_1ea106f1957290e99b6b53cacc8fc53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 26786185, NE, 8.008241254049&lt;/div&gt;`)[0];
#                 popup_4efce78327a118ff3ecd9c25da50839a.setContent(html_1ea106f1957290e99b6b53cacc8fc53a);
#
#
#
#         poly_line_a0cc1f042668ff49f979339adee96dc7.bindPopup(popup_4efce78327a118ff3ecd9c25da50839a)
#         ;
#
#
#
#
#             var poly_line_8b1759fef1d29b54245d40526b0c244e = L.polyline(
#                 [[34.8301903, -115.0440819], [34.8389344, -114.9920261]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e6c4cc67bc4bf224e95d94f52b32d77c);
#
#
#         var popup_e668ddaf133e17f7d868534bc3a40c1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_94b41530230dffebd062f7c7c2165e17 = $(`&lt;div id=&quot;html_94b41530230dffebd062f7c7c2165e17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 178750394, NE, 3.0624698480990005&lt;/div&gt;`)[0];
#                 popup_e668ddaf133e17f7d868534bc3a40c1a.setContent(html_94b41530230dffebd062f7c7c2165e17);
#
#
#
#         poly_line_8b1759fef1d29b54245d40526b0c244e.bindPopup(popup_e668ddaf133e17f7d868534bc3a40c1a)
#         ;
#
#
#
#
#             var poly_line_10aa7114cb47be7dd33fb04856d5153c = L.polyline(
#                 [[34.8389344, -114.9920261], [34.8390215, -114.9916998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e6c4cc67bc4bf224e95d94f52b32d77c);
#
#
#         var popup_50815f3a40e8473c7e14445ec50fbb29 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a66fd93911b62dcd338c3059981cf139 = $(`&lt;div id=&quot;html_a66fd93911b62dcd338c3059981cf139&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 157749424, NE, 0.019443319961&lt;/div&gt;`)[0];
#                 popup_50815f3a40e8473c7e14445ec50fbb29.setContent(html_a66fd93911b62dcd338c3059981cf139);
#
#
#
#         poly_line_10aa7114cb47be7dd33fb04856d5153c.bindPopup(popup_50815f3a40e8473c7e14445ec50fbb29)
#         ;
#
#
#
#
#             var poly_line_aa3aabc554b5a5fb5b7d4fb59366bebe =

# %%
maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
for mp in maps:
    display(mp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32589a1cb204234bd58266b7575ddbd2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32589a1cb204234bd58266b7575ddbd2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32589a1cb204234bd58266b7575ddbd2 = L.map(
#                 &quot;map_32589a1cb204234bd58266b7575ddbd2&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56530b262824e5ffcf118d23c8a157e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32589a1cb204234bd58266b7575ddbd2);
#
#
#             var poly_line_ca11a4303c324999244f2503051a4cc0 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_32589a1cb204234bd58266b7575ddbd2);
#
#
#         var popup_e13cc2a167cb09d79db78868ed3f9d88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3cb92affede2b1d70e4d44ceaf75947 = $(`&lt;div id=&quot;html_c3cb92affede2b1d70e4d44ceaf75947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_e13cc2a167cb09d79db78868ed3f9d88.setContent(html_c3cb92affede2b1d70e4d44ceaf75947);
#
#
#
#         poly_line_ca11a4303c324999244f2503051a4cc0.bindPopup(popup_e13cc2a167cb09d79db78868ed3f9d88)
#         ;
#
#
#
#
#             var poly_line_4fe02e7ed00cd2ccefbfe80999b15b8d = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_32589a1cb204234bd58266b7575ddbd2);
#
#
#         var popup_da74fbadabe4b6cc91c77758f4416086 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52f44299f64aa04465c96a287547f743 = $(`&lt;div id=&quot;html_52f44299f64aa04465c96a287547f743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_da74fbadabe4b6cc91c77758f4416086.setContent(html_52f44299f64aa04465c96a287547f743);
#
#
#
#         poly_line_4fe02e7ed00cd2ccefbfe80999b15b8d.bindPopup(popup_da74fbadabe4b6cc91c77758f4416086)
#         ;
#
#
#
#
#             map_32589a1cb204234bd58266b7575ddbd2.fitBounds(
#                 [[42.2768726, -84.3661974], [42.2918595, -84.2601946]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_446adb1ce61d7a4723a706bcd785f6be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_446adb1ce61d7a4723a706bcd785f6be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_446adb1ce61d7a4723a706bcd785f6be = L.map(
#                 &quot;map_446adb1ce61d7a4723a706bcd785f6be&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ddff2de6a28c54e918e1452d425f1f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_446adb1ce61d7a4723a706bcd785f6be);
#
#
#             var poly_line_3b5a44db3daee824c50575df6863dd09 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_446adb1ce61d7a4723a706bcd785f6be);
#
#
#         var popup_531286849be88fe5822d9c9657e04bb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2433cde41aeb02bbb418d84eb670e459 = $(`&lt;div id=&quot;html_2433cde41aeb02bbb418d84eb670e459&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_531286849be88fe5822d9c9657e04bb6.setContent(html_2433cde41aeb02bbb418d84eb670e459);
#
#
#
#         poly_line_3b5a44db3daee824c50575df6863dd09.bindPopup(popup_531286849be88fe5822d9c9657e04bb6)
#         ;
#
#
#
#
#             var poly_line_43fca16d6b30ba019fdabaea5c6c79d4 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_446adb1ce61d7a4723a706bcd785f6be);
#
#
#         var popup_1f90520f30e8920dbd7dbd699c0e4a40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2ce9443433e0012970200988abc3dd49 = $(`&lt;div id=&quot;html_2ce9443433e0012970200988abc3dd49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_1f90520f30e8920dbd7dbd699c0e4a40.setContent(html_2ce9443433e0012970200988abc3dd49);
#
#
#
#         poly_line_43fca16d6b30ba019fdabaea5c6c79d4.bindPopup(popup_1f90520f30e8920dbd7dbd699c0e4a40)
#         ;
#
#
#
#
#             var poly_line_f085729014edd33fd0cd9a37da40a495 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_446adb1ce61d7a4723a706bcd785f6be);
#
#
#         var popup_004b8a405e31eec592d507c9fbf8ef2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31615aabd7637e7b055a47e59c6b2b2d = $(`&lt;div id=&quot;html_31615aabd7637e7b055a47e59c6b2b2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_004b8a405e31eec592d507c9fbf8ef2b.setContent(html_31615aabd7637e7b055a47e59c6b2b2d);
#
#
#
#         poly_line_f085729014edd33fd0cd9a37da40a495.bindPopup(popup_004b8a405e31eec592d507c9fbf8ef2b)
#         ;
#
#
#
#
#             map_446adb1ce61d7a4723a706bcd785f6be.fitBounds(
#                 [[42
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b692b21bd3efa3ef4711d43cd1b3de1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b692b21bd3efa3ef4711d43cd1b3de1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b692b21bd3efa3ef4711d43cd1b3de1 = L.map(
#                 &quot;map_6b692b21bd3efa3ef4711d43cd1b3de1&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3edf254b30506009e1afb8a728cee1a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b692b21bd3efa3ef4711d43cd1b3de1);
#
#
#             var poly_line_eb965daed3d41f5b21a631ad12228948 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6b692b21bd3efa3ef4711d43cd1b3de1);
#
#
#         var popup_53dd0555e0988bace7ef3eaf966ae6e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdb6b38e27972803a3c35549f7169321 = $(`&lt;div id=&quot;html_bdb6b38e27972803a3c35549f7169321&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_53dd0555e0988bace7ef3eaf966ae6e1.setContent(html_bdb6b38e27972803a3c35549f7169321);
#
#
#
#         poly_line_eb965daed3d41f5b21a631ad12228948.bindPopup(popup_53dd0555e0988bace7ef3eaf966ae6e1)
#         ;
#
#
#
#
#             var poly_line_c0c9d2af2c25ccdfe7a74cd8eb7a087f = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6b692b21bd3efa3ef4711d43cd1b3de1);
#
#
#         var popup_2c3f5a9228cfe4a7725b34756acbee96 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c08e63b631e5debe92bf9badd851841d = $(`&lt;div id=&quot;html_c08e63b631e5debe92bf9badd851841d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_2c3f5a9228cfe4a7725b34756acbee96.setContent(html_c08e63b631e5debe92bf9badd851841d);
#
#
#
#         poly_line_c0c9d2af2c25ccdfe7a74cd8eb7a087f.bindPopup(popup_2c3f5a9228cfe4a7725b34756acbee96)
#         ;
#
#
#
#
#             var poly_line_98df93f4eed1135a96225c9c7c00dd64 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6b692b21bd3efa3ef4711d43cd1b3de1);
#
#
#         var popup_00060aac8f59417c405c65ab1f77a770 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a0f1ba3eeeb3e402f7b40b31f8b79c8 = $(`&lt;div id=&quot;html_7a0f1ba3eeeb3e402f7b40b31f8b79c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_00060aac8f59417c405c65ab1f77a770.setContent(html_7a0f1ba3eeeb3e402f7b40b31f8b79c8);
#
#
#
#         poly_line_98df93f4eed1135a96225c9c7c00dd64.bindPopup(popup_00060aac8f59417c405c65ab1f77a770)
#         ;
#
#
#
#
#             var poly_line_ce9bd1fd39e3fa26c0b6806c53078ebf = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a713753465d07c6e7e81956f46f2c7b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a713753465d07c6e7e81956f46f2c7b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a713753465d07c6e7e81956f46f2c7b8 = L.map(
#                 &quot;map_a713753465d07c6e7e81956f46f2c7b8&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3bd9939861efc18f2daba6f2d49149fd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a713753465d07c6e7e81956f46f2c7b8);
#
#
#             var poly_line_7716b737ef7608702d4926c1b0b0b343 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a713753465d07c6e7e81956f46f2c7b8);
#
#
#         var popup_25f42c94916bcad25cda506a466df529 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7def2c651614307923359631d15df8c7 = $(`&lt;div id=&quot;html_7def2c651614307923359631d15df8c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_25f42c94916bcad25cda506a466df529.setContent(html_7def2c651614307923359631d15df8c7);
#
#
#
#         poly_line_7716b737ef7608702d4926c1b0b0b343.bindPopup(popup_25f42c94916bcad25cda506a466df529)
#         ;
#
#
#
#
#             var poly_line_032d0e0e348c2487f777c14c7bdaf33a = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a713753465d07c6e7e81956f46f2c7b8);
#
#
#         var popup_4d1ee092cf0ed1bdafa58574f836195d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bc0ace3bef91b21271c9a731b7317fa = $(`&lt;div id=&quot;html_6bc0ace3bef91b21271c9a731b7317fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_4d1ee092cf0ed1bdafa58574f836195d.setContent(html_6bc0ace3bef91b21271c9a731b7317fa);
#
#
#
#         poly_line_032d0e0e348c2487f777c14c7bdaf33a.bindPopup(popup_4d1ee092cf0ed1bdafa58574f836195d)
#         ;
#
#
#
#
#             var poly_line_554ecbcae886f0b0a825f9d4fbeaf0a4 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a713753465d07c6e7e81956f46f2c7b8);
#
#
#         var popup_17990510e7a1738f3016d673bf636598 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c9bc1391bbf6275cc9c4e5ed65a64cb = $(`&lt;div id=&quot;html_1c9bc1391bbf6275cc9c4e5ed65a64cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_17990510e7a1738f3016d673bf636598.setContent(html_1c9bc1391bbf6275cc9c4e5ed65a64cb);
#
#
#
#         poly_line_554ecbcae886f0b0a825f9d4fbeaf0a4.bindPopup(popup_17990510e7a1738f3016d673bf636598)
#         ;
#
#
#
#
#             var poly_line_d459b92aa1fceaf6c7508bf925caa514 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8672044fde30a8d8973687f5974d36f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8672044fde30a8d8973687f5974d36f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8672044fde30a8d8973687f5974d36f = L.map(
#                 &quot;map_f8672044fde30a8d8973687f5974d36f&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee08971223a5dce92925070bf738c4ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f8672044fde30a8d8973687f5974d36f);
#
#
#             var poly_line_9966f81366b199b852e4adf006eb2218 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f8672044fde30a8d8973687f5974d36f);
#
#
#         var popup_33b2b1b41a26b8514de4f7563a0e9149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f33738baed489d5b1ed72a981770bc93 = $(`&lt;div id=&quot;html_f33738baed489d5b1ed72a981770bc93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_33b2b1b41a26b8514de4f7563a0e9149.setContent(html_f33738baed489d5b1ed72a981770bc93);
#
#
#
#         poly_line_9966f81366b199b852e4adf006eb2218.bindPopup(popup_33b2b1b41a26b8514de4f7563a0e9149)
#         ;
#
#
#
#
#             var poly_line_86380debcc14d6f490fbfd72d4a77591 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f8672044fde30a8d8973687f5974d36f);
#
#
#         var popup_f0bfb126b4d10a417ef7c0d2f7912b5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5d0756798c45819745faa23c907b996 = $(`&lt;div id=&quot;html_d5d0756798c45819745faa23c907b996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_f0bfb126b4d10a417ef7c0d2f7912b5d.setContent(html_d5d0756798c45819745faa23c907b996);
#
#
#
#         poly_line_86380debcc14d6f490fbfd72d4a77591.bindPopup(popup_f0bfb126b4d10a417ef7c0d2f7912b5d)
#         ;
#
#
#
#
#             var poly_line_14975e47833c90e49ba4225c1d5c9065 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f8672044fde30a8d8973687f5974d36f);
#
#
#         var popup_7d514d6ba3a72324b9ed3a62a6c9d5cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5b1587a5770fabb77f6ba85c740d3a9 = $(`&lt;div id=&quot;html_f5b1587a5770fabb77f6ba85c740d3a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_7d514d6ba3a72324b9ed3a62a6c9d5cd.setContent(html_f5b1587a5770fabb77f6ba85c740d3a9);
#
#
#
#         poly_line_14975e47833c90e49ba4225c1d5c9065.bindPopup(popup_7d514d6ba3a72324b9ed3a62a6c9d5cd)
#         ;
#
#
#
#
#             var poly_line_eede50911346269c94e62ffd8d953d21 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91790b9be5207d8e442f68c1443118d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91790b9be5207d8e442f68c1443118d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91790b9be5207d8e442f68c1443118d1 = L.map(
#                 &quot;map_91790b9be5207d8e442f68c1443118d1&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07846909fb2a7bd86326c702dbb15d76 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_91790b9be5207d8e442f68c1443118d1);
#
#
#             var poly_line_2eabb749217044adce1168b4300508e8 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_91790b9be5207d8e442f68c1443118d1);
#
#
#         var popup_cf8bc7c7b5e95ade1782d331fe424651 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8c12ff465ca1a1f30254a74002e7779 = $(`&lt;div id=&quot;html_a8c12ff465ca1a1f30254a74002e7779&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_cf8bc7c7b5e95ade1782d331fe424651.setContent(html_a8c12ff465ca1a1f30254a74002e7779);
#
#
#
#         poly_line_2eabb749217044adce1168b4300508e8.bindPopup(popup_cf8bc7c7b5e95ade1782d331fe424651)
#         ;
#
#
#
#
#             var poly_line_910a972e6813ef84e8a7920427b0c4db = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_91790b9be5207d8e442f68c1443118d1);
#
#
#         var popup_ffd0bb35cf3ae70af1a22acf2c83d6df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_931deaefb5ddfc2e9aaad69a5741cdd1 = $(`&lt;div id=&quot;html_931deaefb5ddfc2e9aaad69a5741cdd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_ffd0bb35cf3ae70af1a22acf2c83d6df.setContent(html_931deaefb5ddfc2e9aaad69a5741cdd1);
#
#
#
#         poly_line_910a972e6813ef84e8a7920427b0c4db.bindPopup(popup_ffd0bb35cf3ae70af1a22acf2c83d6df)
#         ;
#
#
#
#
#             var poly_line_bf2209d1339afa82ffcd679d45127d99 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_91790b9be5207d8e442f68c1443118d1);
#
#
#         var popup_052ef45051ae99fe8afbd7262ddb4adb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d4934960c1213efb5ceb9abbed7a82c = $(`&lt;div id=&quot;html_4d4934960c1213efb5ceb9abbed7a82c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_052ef45051ae99fe8afbd7262ddb4adb.setContent(html_4d4934960c1213efb5ceb9abbed7a82c);
#
#
#
#         poly_line_bf2209d1339afa82ffcd679d45127d99.bindPopup(popup_052ef45051ae99fe8afbd7262ddb4adb)
#         ;
#
#
#
#
#             var poly_line_b74c542f8a684893561efdb2830fd679 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_424f0b8da8e43de075dd10985d69bbb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_424f0b8da8e43de075dd10985d69bbb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_424f0b8da8e43de075dd10985d69bbb2 = L.map(
#                 &quot;map_424f0b8da8e43de075dd10985d69bbb2&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb6aa199e3572e51c6017e36b4120b9b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_424f0b8da8e43de075dd10985d69bbb2);
#
#
#             var poly_line_56df5c4bc12104769e953684fb7b0c49 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_424f0b8da8e43de075dd10985d69bbb2);
#
#
#         var popup_03fc47ae7c4af8fe5311f7a6408b7ce4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89e6cb605296eeab6b82755b384b18ae = $(`&lt;div id=&quot;html_89e6cb605296eeab6b82755b384b18ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_03fc47ae7c4af8fe5311f7a6408b7ce4.setContent(html_89e6cb605296eeab6b82755b384b18ae);
#
#
#
#         poly_line_56df5c4bc12104769e953684fb7b0c49.bindPopup(popup_03fc47ae7c4af8fe5311f7a6408b7ce4)
#         ;
#
#
#
#
#             var poly_line_13c7f6849efad1424ebf4a7c94eee93c = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_424f0b8da8e43de075dd10985d69bbb2);
#
#
#         var popup_c035efdd704c21a8515ad1150d2d28d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cabfbe8a25c2ad31b85b7f5b83cfd4f = $(`&lt;div id=&quot;html_2cabfbe8a25c2ad31b85b7f5b83cfd4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_c035efdd704c21a8515ad1150d2d28d1.setContent(html_2cabfbe8a25c2ad31b85b7f5b83cfd4f);
#
#
#
#         poly_line_13c7f6849efad1424ebf4a7c94eee93c.bindPopup(popup_c035efdd704c21a8515ad1150d2d28d1)
#         ;
#
#
#
#
#             var poly_line_56e255c2ebd1fecff880b369bf65f620 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_424f0b8da8e43de075dd10985d69bbb2);
#
#
#         var popup_4d0c9d6dfbc35f032c42d376c7439781 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b51512d9afd02ef164d956f141fb92c3 = $(`&lt;div id=&quot;html_b51512d9afd02ef164d956f141fb92c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_4d0c9d6dfbc35f032c42d376c7439781.setContent(html_b51512d9afd02ef164d956f141fb92c3);
#
#
#
#         poly_line_56e255c2ebd1fecff880b369bf65f620.bindPopup(popup_4d0c9d6dfbc35f032c42d376c7439781)
#         ;
#
#
#
#
#             var poly_line_c00543c629f9a11833865f37f33efe96 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed9ef37fe76d6066438c60f3f0d60105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed9ef37fe76d6066438c60f3f0d60105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed9ef37fe76d6066438c60f3f0d60105 = L.map(
#                 &quot;map_ed9ef37fe76d6066438c60f3f0d60105&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70fd4b602a04a943514b83f857dc5ba5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed9ef37fe76d6066438c60f3f0d60105);
#
#
#             var poly_line_2b9d12ec5ae96fa353f5529ba38305d1 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ed9ef37fe76d6066438c60f3f0d60105);
#
#
#         var popup_0af0331d5b5377260dbb5ab6c43a90ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a06b817d1105b58c1db9e55b7484fe07 = $(`&lt;div id=&quot;html_a06b817d1105b58c1db9e55b7484fe07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_0af0331d5b5377260dbb5ab6c43a90ba.setContent(html_a06b817d1105b58c1db9e55b7484fe07);
#
#
#
#         poly_line_2b9d12ec5ae96fa353f5529ba38305d1.bindPopup(popup_0af0331d5b5377260dbb5ab6c43a90ba)
#         ;
#
#
#
#
#             var poly_line_799f566a35d5e412897dd446e8720b8e = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ed9ef37fe76d6066438c60f3f0d60105);
#
#
#         var popup_d0594e7b530c6411a659205cb193e4c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b0ca7177e5c94adf8680b622e3ac037 = $(`&lt;div id=&quot;html_5b0ca7177e5c94adf8680b622e3ac037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_d0594e7b530c6411a659205cb193e4c5.setContent(html_5b0ca7177e5c94adf8680b622e3ac037);
#
#
#
#         poly_line_799f566a35d5e412897dd446e8720b8e.bindPopup(popup_d0594e7b530c6411a659205cb193e4c5)
#         ;
#
#
#
#
#             var poly_line_3a6f911d29607ad4cd0832a149f20a24 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_ed9ef37fe76d6066438c60f3f0d60105);
#
#
#         var popup_771f5561d357d635954011489f05f500 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2fcfbac7536f7523acc712f726f715f = $(`&lt;div id=&quot;html_c2fcfbac7536f7523acc712f726f715f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_771f5561d357d635954011489f05f500.setContent(html_c2fcfbac7536f7523acc712f726f715f);
#
#
#
#         poly_line_3a6f911d29607ad4cd0832a149f20a24.bindPopup(popup_771f5561d357d635954011489f05f500)
#         ;
#
#
#
#
#             var poly_line_c561c537b9ce982f01a46573c4cb165e = L.polyline(
