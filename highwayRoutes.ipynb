# %%
from src.mapping import mapper
mapper = mapper()

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Expected Distance 31.52 miles
# Expected Time: 27 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e64195eb2b2ad272a0f5f378caad5403 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e64195eb2b2ad272a0f5f378caad5403&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e64195eb2b2ad272a0f5f378caad5403 = L.map(
#                 &quot;map_e64195eb2b2ad272a0f5f378caad5403&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef98a6fdc48b651e8c9e9b4ef37657f1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e64195eb2b2ad272a0f5f378caad5403);
#
#
#             var poly_line_4b4c5d38af7ef9c1cb31fd42ea66f07d = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e64195eb2b2ad272a0f5f378caad5403);
#
#
#         var popup_8858b749d03d95451157bbadec5ea4c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e66bbee03dae9f38f7945bcf537507db = $(`&lt;div id=&quot;html_e66bbee03dae9f38f7945bcf537507db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_8858b749d03d95451157bbadec5ea4c5.setContent(html_e66bbee03dae9f38f7945bcf537507db);
#
#
#
#         poly_line_4b4c5d38af7ef9c1cb31fd42ea66f07d.bindPopup(popup_8858b749d03d95451157bbadec5ea4c5)
#         ;
#
#
#
#
#             var poly_line_0d9c9b996a08538bcc4df118e792f7e3 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e64195eb2b2ad272a0f5f378caad5403);
#
#
#         var popup_68b0cde97159d9348b61bd6efda81ef0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0661aa5d26305c4ed8d9a15db121760 = $(`&lt;div id=&quot;html_c0661aa5d26305c4ed8d9a15db121760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_68b0cde97159d9348b61bd6efda81ef0.setContent(html_c0661aa5d26305c4ed8d9a15db121760);
#
#
#
#         poly_line_0d9c9b996a08538bcc4df118e792f7e3.bindPopup(popup_68b0cde97159d9348b61bd6efda81ef0)
#         ;
#
#
#
#
#             var poly_line_030dc96af0f1c73cb29a5895031424d9 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_e64195eb2b2ad272a0f5f378caad5403);
#
#
#         var popup_f7bd31b68bf89ba6a5e24524b1923bd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71c2679134aef9132e3e137fe62f0a10 = $(`&lt;div id=&quot;html_71c2679134aef9132e3e137fe62f0a10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_f7bd31b68bf89ba6a5e24524b1923bd4.setContent(html_71c2679134aef9132e3e137fe62f0a10);
#
#
#
#         poly_line_030dc96af0f1c73cb29a5895031424d9.bindPopup(popup_f7bd31b68bf89ba6a5e24524b1923bd4)
#         ;
#
#
#
#
#             var poly_line_01c8e17a1b2048b877d29127bc186ea6 =

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 129.59 miles
# Expected Time: 1 hrs 43 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ecaca7bd67fcea1ad124ddefa849fa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ecaca7bd67fcea1ad124ddefa849fa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ecaca7bd67fcea1ad124ddefa849fa4 = L.map(
#                 &quot;map_9ecaca7bd67fcea1ad124ddefa849fa4&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d04b5370878d42a28493ce54c522398 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9ecaca7bd67fcea1ad124ddefa849fa4);
#
#
#             var poly_line_4cdece4656d5f71d8dd9cc4d9534d56f = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9ecaca7bd67fcea1ad124ddefa849fa4);
#
#
#         var popup_af99245d10a661decd5212b337d8b124 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ec943eb91220a9a0fcafd53613c393f = $(`&lt;div id=&quot;html_1ec943eb91220a9a0fcafd53613c393f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 849020694, SE, 0.405516035165&lt;/div&gt;`)[0];
#                 popup_af99245d10a661decd5212b337d8b124.setContent(html_1ec943eb91220a9a0fcafd53613c393f);
#
#
#
#         poly_line_4cdece4656d5f71d8dd9cc4d9534d56f.bindPopup(popup_af99245d10a661decd5212b337d8b124)
#         ;
#
#
#
#
#             var poly_line_a4673f5d5e248a2a04bdecf75fe82962 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9ecaca7bd67fcea1ad124ddefa849fa4);
#
#
#         var popup_48f5e8f376fc3b4e93296c026e8995a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e9f1a2e0c0fd7d9e74d99c86bd100a2 = $(`&lt;div id=&quot;html_1e9f1a2e0c0fd7d9e74d99c86bd100a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447120, SE, 0.015121684655999999&lt;/div&gt;`)[0];
#                 popup_48f5e8f376fc3b4e93296c026e8995a2.setContent(html_1e9f1a2e0c0fd7d9e74d99c86bd100a2);
#
#
#
#         poly_line_a4673f5d5e248a2a04bdecf75fe82962.bindPopup(popup_48f5e8f376fc3b4e93296c026e8995a2)
#         ;
#
#
#
#
#             var poly_line_5e05055f277a824ad14ccb5c98381878 = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9ecaca7bd67fcea1ad124ddefa849fa4);
#
#
#         var popup_ffde967463f4e2c648be33b3486c1ad4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d525119d7773dc0b0a6dff295bcdf82d = $(`&lt;div id=&quot;html_d525119d7773dc0b0a6dff295bcdf82d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447112, SE, 0.36979217363300004&lt;/div&gt;`)[0];
#                 popup_ffde967463f4e2c648be33b3486c1ad4.setContent(html_d525119d7773dc0b0a6dff295bcdf82d);
#
#
#
#         poly_line_5e05055f277a824ad14ccb5c98381878.bindPopup(popup_ffde967463f4e2c648be33b3486c1ad4)
#         ;
#
#
#
#
#             var poly_line_a669ad

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 392.30 miles
# Expected Time: 5 hrs 17 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_342eea72648af5c3cbc426f4c7d898cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_342eea72648af5c3cbc426f4c7d898cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_342eea72648af5c3cbc426f4c7d898cb = L.map(
#                 &quot;map_342eea72648af5c3cbc426f4c7d898cb&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee360f66374c7d6087c44cd0b1b5b249 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_342eea72648af5c3cbc426f4c7d898cb);
#
#
#             var poly_line_bdf8559e1a74c4a3624f214431e50d44 = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_342eea72648af5c3cbc426f4c7d898cb);
#
#
#         var popup_d40fa808afe2a816034b42d7add84ae4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ccf0f4ac6ccabb4db677da1f1ae3453 = $(`&lt;div id=&quot;html_7ccf0f4ac6ccabb4db677da1f1ae3453&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 26786185, NE, 8.008241254049&lt;/div&gt;`)[0];
#                 popup_d40fa808afe2a816034b42d7add84ae4.setContent(html_7ccf0f4ac6ccabb4db677da1f1ae3453);
#
#
#
#         poly_line_bdf8559e1a74c4a3624f214431e50d44.bindPopup(popup_d40fa808afe2a816034b42d7add84ae4)
#         ;
#
#
#
#
#             var poly_line_430d7195779d78e2a8267614ee92be42 = L.polyline(
#                 [[34.8301903, -115.0440819], [34.8389344, -114.9920261]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_342eea72648af5c3cbc426f4c7d898cb);
#
#
#         var popup_09ff62a2f04ccd5166bdd52b2d0c3881 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05885bf2aab3ce1fc11d0d3e1292eba3 = $(`&lt;div id=&quot;html_05885bf2aab3ce1fc11d0d3e1292eba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 178750394, NE, 3.0624698480990005&lt;/div&gt;`)[0];
#                 popup_09ff62a2f04ccd5166bdd52b2d0c3881.setContent(html_05885bf2aab3ce1fc11d0d3e1292eba3);
#
#
#
#         poly_line_430d7195779d78e2a8267614ee92be42.bindPopup(popup_09ff62a2f04ccd5166bdd52b2d0c3881)
#         ;
#
#
#
#
#             var poly_line_5162181219459f0e2da4e2a1e1896217 = L.polyline(
#                 [[34.8389344, -114.9920261], [34.8390215, -114.9916998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_342eea72648af5c3cbc426f4c7d898cb);
#
#
#         var popup_7da62b0bcc786e97bba2356b094cb026 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62d2f2ce9c058726dfb9fec9dea444e3 = $(`&lt;div id=&quot;html_62d2f2ce9c058726dfb9fec9dea444e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 157749424, NE, 0.019443319961&lt;/div&gt;`)[0];
#                 popup_7da62b0bcc786e97bba2356b094cb026.setContent(html_62d2f2ce9c058726dfb9fec9dea444e3);
#
#
#
#         poly_line_5162181219459f0e2da4e2a1e1896217.bindPopup(popup_7da62b0bcc786e97bba2356b094cb026)
#         ;
#
#
#
#
#             var poly_line_d96fdef6acfbe5f9eb73712f5694dcef =

# %%
maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
for mp in maps:
    display(mp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> for mp in maps:
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     display(mp)
#
# File ~/Documents/GitHub/TriRoutes/src/highwayRouter.py:84, in HighwayRouter.routeMaps(self, slat, slon, elat, elon)
#      83 def routeMaps(self, slat, slon, elat, elon):
# ---> 84     init = self.hw.getEndWays(slat, slon, elat, elon)
#      85     maps = self.AstarMaps(init['startWay'], init['endWay'], elat, elon)
#      86     return maps
#
# AttributeError: 'network' object has no attribute 'getEndWays'
