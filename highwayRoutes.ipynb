# %%
import folium
from src.mapping import mapper

# %%
mapper = mapper()

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Expected Distance 14.29 miles
# Expected Time: 12 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = mapper.mapHighways([42.228708, -84.935065], [42.344618, -84.294575])
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> m = mapper.mapHighways([42.228708, -84.935065], [42.344618, -84.294575])
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> m
#
# File ~/Documents/GitHub/TriRoutes/src/mapping.py:24, in mapper.mapHighways(self, s, e)
#      22 # get all ways in our network where the start is contained in our bounding box
#      23 ways = []
# ---> 24 for way in self.hw.ways.values():
#      25     start = way['startNode']
#      26     if (start['lat'] > slat and start['lat'] < elat) and (start['long'] > slon and start['long'] < elon):
#
# ...

# %%
m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> m
#
# File ~/Documents/GitHub/TriRoutes/src/mapping.py:63, in mapper.mapEndWays(self, s, e)
#      61 seNode = startWay.end
#      62 endWay = endWays['end']
# ---> 63 esNode = endWay.start
#      64 eeNode = endWay.end
#      66 # append coordinates
#
# AttributeError: 'NoneType' object has no attribute 'start'

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Expected Distance 31.56 miles
# Expected Time: 27 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = mapper.mapEndWays([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 86.69 miles
# Expected Time: 1 hrs 23 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = mapper.mapEndWays([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 210.92 miles
# Expected Time: 2 hrs 51 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
for mp in maps:
    display(mp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> for mp in maps:
#       <a href='vscode-notebook-cell:/Users/walkerbagley/Documents/GitHub/TriRoutes/highwayRoutes.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     display(mp)
#
# File ~/Documents/GitHub/TriRoutes/src/highwayRouter.py:83, in HighwayRouter.routeMaps(self, slat, slon, elat, elon)
#      82 def routeMaps(self, slat, slon, elat, elon):
# ---> 83     init = self.hw.getEndWays(slat, slon, elat, elon)
# ...
