# %%
from src.mapping import mapper
mapper = mapper(5000)

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Roads searched: 33
# Search Time: 0.00669 s
#
# Expected Distance 31.52 miles
# Expected Time: 27 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f21d60983116b7c4e98dfcb00834f391 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f21d60983116b7c4e98dfcb00834f391&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f21d60983116b7c4e98dfcb00834f391 = L.map(
#                 &quot;map_f21d60983116b7c4e98dfcb00834f391&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f8cc20507fe29d87377b58b30429ca1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f21d60983116b7c4e98dfcb00834f391);
#
#
#             var poly_line_d061a44f00784122f65e7f6378f2a548 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f21d60983116b7c4e98dfcb00834f391);
#
#
#         var popup_56cc6b02257fd8ea632384c7214b0ef8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_921ea8b1af1526136bc584fe7ab37f44 = $(`&lt;div id=&quot;html_921ea8b1af1526136bc584fe7ab37f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_56cc6b02257fd8ea632384c7214b0ef8.setContent(html_921ea8b1af1526136bc584fe7ab37f44);
#
#
#
#         poly_line_d061a44f00784122f65e7f6378f2a548.bindPopup(popup_56cc6b02257fd8ea632384c7214b0ef8)
#         ;
#
#
#
#
#             var poly_line_fc147f50bcca5646aca348121b37bd28 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f21d60983116b7c4e98dfcb00834f391);
#
#
#         var popup_8107007a1ba428899036f5142306816d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e22d61bcecbb8d59f6b8a33846d4ff30 = $(`&lt;div id=&quot;html_e22d61bcecbb8d59f6b8a33846d4ff30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_8107007a1ba428899036f5142306816d.setContent(html_e22d61bcecbb8d59f6b8a33846d4ff30);
#
#
#
#         poly_line_fc147f50bcca5646aca348121b37bd28.bindPopup(popup_8107007a1ba428899036f5142306816d)
#         ;
#
#
#
#
#             var poly_line_5ebb53663a8220ad66a4314fe55a4dcd = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f21d60983116b7c4e98dfcb00834f391);
#
#
#         var popup_e2feec4b94819e1d568b6f14eb45f18b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3d56c904128bc58b7558b8e0b1764fb = $(`&lt;div id=&quot;html_a3d56c904128bc58b7558b8e0b1764fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_e2feec4b94819e1d568b6f14eb45f18b.setContent(html_a3d56c904128bc58b7558b8e0b1764fb);
#
#
#
#         poly_line_5ebb53663a8220ad66a4314fe55a4dcd.bindPopup(popup_e2feec4b94819e1d568b6f14eb45f18b)
#         ;
#
#
#
#
#             var poly_line_1b8b10db88d52265c0385e3d7d3accd1 =

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# Roads searched: 112
# Search Time: 0.09124 s
#
# Expected Distance 129.59 miles
# Expected Time: 1 hrs 43 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41505710beb42ba38da516edf8d4f004 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41505710beb42ba38da516edf8d4f004&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41505710beb42ba38da516edf8d4f004 = L.map(
#                 &quot;map_41505710beb42ba38da516edf8d4f004&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28d1a8cd6156f3d7ca8713a22e9c856e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41505710beb42ba38da516edf8d4f004);
#
#
#             var poly_line_b56a74dfc31dd56b3890f74ec972ac33 = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_41505710beb42ba38da516edf8d4f004);
#
#
#         var popup_6e5d8cf21e227b5c1d77f52b593c16dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47c856a9343d28f3dfb04f0d371bd63f = $(`&lt;div id=&quot;html_47c856a9343d28f3dfb04f0d371bd63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 849020694, SE, 0.405516035165&lt;/div&gt;`)[0];
#                 popup_6e5d8cf21e227b5c1d77f52b593c16dd.setContent(html_47c856a9343d28f3dfb04f0d371bd63f);
#
#
#
#         poly_line_b56a74dfc31dd56b3890f74ec972ac33.bindPopup(popup_6e5d8cf21e227b5c1d77f52b593c16dd)
#         ;
#
#
#
#
#             var poly_line_d77f50dbfa619beea46c9a1c2ae21576 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_41505710beb42ba38da516edf8d4f004);
#
#
#         var popup_233abb566d230098fb2a084dd97cf456 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8459b8eec234aa295c3f685d20914f43 = $(`&lt;div id=&quot;html_8459b8eec234aa295c3f685d20914f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447120, SE, 0.015121684655999999&lt;/div&gt;`)[0];
#                 popup_233abb566d230098fb2a084dd97cf456.setContent(html_8459b8eec234aa295c3f685d20914f43);
#
#
#
#         poly_line_d77f50dbfa619beea46c9a1c2ae21576.bindPopup(popup_233abb566d230098fb2a084dd97cf456)
#         ;
#
#
#
#
#             var poly_line_468126fa5362843ba405c33591a71ba1 = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_41505710beb42ba38da516edf8d4f004);
#
#
#         var popup_112ad0012bcedb39dac403d34fce0ff5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bd04ec328517202e72d0757abfe4dfd = $(`&lt;div id=&quot;html_6bd04ec328517202e72d0757abfe4dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447112, SE, 0.36979217363300004&lt;/div&gt;`)[0];
#                 popup_112ad0012bcedb39dac403d34fce0ff5.setContent(html_6bd04ec328517202e72d0757abfe4dfd);
#
#
#
#         poly_line_468126fa5362843ba405c33591a71ba1.bindPopup(popup_112ad0012bcedb39dac403d34fce0ff5)
#         ;
#
#
#
#
#             var poly_line_6d99d5

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# Roads searched: 588
# Search Time: 2.43929 s
#
# Expected Distance 392.30 miles
# Expected Time: 5 hrs 17 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc37a3f690312a402a1e203a979361ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc37a3f690312a402a1e203a979361ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc37a3f690312a402a1e203a979361ba = L.map(
#                 &quot;map_fc37a3f690312a402a1e203a979361ba&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99b384eaad10688f501988c46695a3dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fc37a3f690312a402a1e203a979361ba);
#
#
#             var poly_line_5bd4577fcc520967505caecb81bbd560 = L.polyline(
#                 [[34.8127386, -115.1836298], [34.8301903, -115.0440819]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fc37a3f690312a402a1e203a979361ba);
#
#
#         var popup_92ae479a07b2a21888288758cba03437 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b23f79636df9b174c14eef1eebf2ae38 = $(`&lt;div id=&quot;html_b23f79636df9b174c14eef1eebf2ae38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 26786185, NE, 8.008241254049&lt;/div&gt;`)[0];
#                 popup_92ae479a07b2a21888288758cba03437.setContent(html_b23f79636df9b174c14eef1eebf2ae38);
#
#
#
#         poly_line_5bd4577fcc520967505caecb81bbd560.bindPopup(popup_92ae479a07b2a21888288758cba03437)
#         ;
#
#
#
#
#             var poly_line_413d847ac69b4ea23fab6b2142ce48af = L.polyline(
#                 [[34.8301903, -115.0440819], [34.8389344, -114.9920261]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fc37a3f690312a402a1e203a979361ba);
#
#
#         var popup_71a563d24dc51ae16fa4374d1bf2e12f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e94cf5fea0cf664c7e3cbd711c188893 = $(`&lt;div id=&quot;html_e94cf5fea0cf664c7e3cbd711c188893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 178750394, NE, 3.0624698480990005&lt;/div&gt;`)[0];
#                 popup_71a563d24dc51ae16fa4374d1bf2e12f.setContent(html_e94cf5fea0cf664c7e3cbd711c188893);
#
#
#
#         poly_line_413d847ac69b4ea23fab6b2142ce48af.bindPopup(popup_71a563d24dc51ae16fa4374d1bf2e12f)
#         ;
#
#
#
#
#             var poly_line_ef38ca0c98acac607f4fc8801011bbde = L.polyline(
#                 [[34.8389344, -114.9920261], [34.8390215, -114.9916998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fc37a3f690312a402a1e203a979361ba);
#
#
#         var popup_4134352c35fbe6b91fba8ab17e4507b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f456001d1a756ac3e8e4c30cc7b8d5b9 = $(`&lt;div id=&quot;html_f456001d1a756ac3e8e4c30cc7b8d5b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40, 157749424, NE, 0.019443319961&lt;/div&gt;`)[0];
#                 popup_4134352c35fbe6b91fba8ab17e4507b0.setContent(html_f456001d1a756ac3e8e4c30cc7b8d5b9);
#
#
#
#         poly_line_ef38ca0c98acac607f4fc8801011bbde.bindPopup(popup_4134352c35fbe6b91fba8ab17e4507b0)
#         ;
#
#
#
#
#             var poly_line_87a8383cf1b1cba891ce06b2956c01c7 =

# %%
m = mapper.mapRoute([41.704884, -91.085750], [46.819699, -113.327837])
m
# Out:
# Roads searched: 5000
# Search Time: 33.94815 s
#
# Expected Distance 954.54 miles
# Expected Time: 13 hrs 5 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_908e2645bec82c52a144d1f73e37a874 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_908e2645bec82c52a144d1f73e37a874&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_908e2645bec82c52a144d1f73e37a874 = L.map(
#                 &quot;map_908e2645bec82c52a144d1f73e37a874&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9124fab0a6c809fe5e7f7ad436e492ac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_908e2645bec82c52a144d1f73e37a874);
#
#
#             var poly_line_1554dfb89e567ee91d6b678dc2f933f2 = L.polyline(
#                 [[41.645008, -91.1093082], [41.645572, -91.131427]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_908e2645bec82c52a144d1f73e37a874);
#
#
#         var popup_8c10f60822418fba4e88b061f196deef = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f47f6ce70ee153900783a145b17d2782 = $(`&lt;div id=&quot;html_f47f6ce70ee153900783a145b17d2782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 80, 158128039, NW, 1.141878573796&lt;/div&gt;`)[0];
#                 popup_8c10f60822418fba4e88b061f196deef.setContent(html_f47f6ce70ee153900783a145b17d2782);
#
#
#
#         poly_line_1554dfb89e567ee91d6b678dc2f933f2.bindPopup(popup_8c10f60822418fba4e88b061f196deef)
#         ;
#
#
#
#
#             var poly_line_970a903236b553ab825031f5d7086694 = L.polyline(
#                 [[41.645572, -91.131427], [41.6456996, -91.1359101]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_908e2645bec82c52a144d1f73e37a874);
#
#
#         var popup_ca4d2a47b4480fc8959347b59fe6b903 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b9bc09f8a86754bd2bb86ef8afeb532 = $(`&lt;div id=&quot;html_9b9bc09f8a86754bd2bb86ef8afeb532&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 80, 51260464, NW, 0.231461318871&lt;/div&gt;`)[0];
#                 popup_ca4d2a47b4480fc8959347b59fe6b903.setContent(html_9b9bc09f8a86754bd2bb86ef8afeb532);
#
#
#
#         poly_line_970a903236b553ab825031f5d7086694.bindPopup(popup_ca4d2a47b4480fc8959347b59fe6b903)
#         ;
#
#
#
#
#             var poly_line_d2def925223d3442ee3544aa930e20e3 = L.polyline(
#                 [[41.6456996, -91.1359101], [41.6619401, -91.2287505]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_908e2645bec82c52a144d1f73e37a874);
#
#
#         var popup_fe171b31a860df0f3e767eff143d8b72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a21e2d8d4d2b7ad5d05b23ad586d53e8 = $(`&lt;div id=&quot;html_a21e2d8d4d2b7ad5d05b23ad586d53e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 80, 51260463, NW, 4.977972715283&lt;/div&gt;`)[0];
#                 popup_fe171b31a860df0f3e767eff143d8b72.setContent(html_a21e2d8d4d2b7ad5d05b23ad586d53e8);
#
#
#
#         poly_line_d2def925223d3442ee3544aa930e20e3.bindPopup(popup_fe171b31a860df0f3e767eff143d8b72)
#         ;
#
#
#
#
#             var poly_line_ef2d7f58e95334beb08e1cd860d64422 = L.polyline(

# %%
maps = mapper.router.routeMaps(41.604884, -91.085750, 46.819699, -113.327837)
for mp in maps:
    display(mp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b9408b58595edd73ef4323b2c6d45aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b9408b58595edd73ef4323b2c6d45aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b9408b58595edd73ef4323b2c6d45aa = L.map(
#                 &quot;map_9b9408b58595edd73ef4323b2c6d45aa&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c70259c52a75c71e7f87bffdbc52eab8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9b9408b58595edd73ef4323b2c6d45aa);
#
#
#             var poly_line_54eabd13f37d60342426b378de734665 = L.polyline(
#                 [[41.6045679, -91.0361029], [41.6048483, -91.0360948]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9b9408b58595edd73ef4323b2c6d45aa);
#
#
#         var popup_de7b4b8b48fe46b4a56f07898462aab5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1944d8233cd964b401ed4c36dfefdbe4 = $(`&lt;div id=&quot;html_1944d8233cd964b401ed4c36dfefdbe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, NE, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_de7b4b8b48fe46b4a56f07898462aab5.setContent(html_1944d8233cd964b401ed4c36dfefdbe4);
#
#
#
#         poly_line_54eabd13f37d60342426b378de734665.bindPopup(popup_de7b4b8b48fe46b4a56f07898462aab5)
#         ;
#
#
#
#
#             var poly_line_201e11add2ea55c4264a6bfbfeba1641 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.63509, -91.0357385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9b9408b58595edd73ef4323b2c6d45aa);
#
#
#         var popup_37ea83f930e599701964af220ee4ccc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_468021187bca780540cea9f7b9a2a369 = $(`&lt;div id=&quot;html_468021187bca780540cea9f7b9a2a369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 158128050, NE, 2.088140857598&lt;/div&gt;`)[0];
#                 popup_37ea83f930e599701964af220ee4ccc6.setContent(html_468021187bca780540cea9f7b9a2a369);
#
#
#
#         poly_line_201e11add2ea55c4264a6bfbfeba1641.bindPopup(popup_37ea83f930e599701964af220ee4ccc6)
#         ;
#
#
#
#
#             var poly_line_01ee3980cf7e265e7847dc906474f126 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.6045679, -91.0361029]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_9b9408b58595edd73ef4323b2c6d45aa);
#
#
#         var popup_9cdd75e52762f5a4682f78ae7efc2789 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb04ad294bc37920583177073347adbf = $(`&lt;div id=&quot;html_eb04ad294bc37920583177073347adbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, SW, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_9cdd75e52762f5a4682f78ae7efc2789.setContent(html_eb04ad294bc37920583177073347adbf);
#
#
#
#         poly_line_01ee3980cf7e265e7847dc906474f126.bindPopup(popup_9cdd75e52762f5a4682f78ae7efc2789)
#         ;
#
#
#
#
#             map_9b9408b58595edd73ef4323b2c6d45aa.fitBounds(
#                 [[41.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8a93e9bcce2d674be650c7f2b95b312 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8a93e9bcce2d674be650c7f2b95b312&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8a93e9bcce2d674be650c7f2b95b312 = L.map(
#                 &quot;map_a8a93e9bcce2d674be650c7f2b95b312&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a734c391208239a05f0accf77c1409 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8a93e9bcce2d674be650c7f2b95b312);
#
#
#             var poly_line_1498df8e873ef4a2a73087558a1451bf = L.polyline(
#                 [[41.6045679, -91.0361029], [41.6048483, -91.0360948]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a8a93e9bcce2d674be650c7f2b95b312);
#
#
#         var popup_95d3bbb61fac799420dfa670e60f1544 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c2fec9292e1e7452339fadb49af513f = $(`&lt;div id=&quot;html_5c2fec9292e1e7452339fadb49af513f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, NE, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_95d3bbb61fac799420dfa670e60f1544.setContent(html_5c2fec9292e1e7452339fadb49af513f);
#
#
#
#         poly_line_1498df8e873ef4a2a73087558a1451bf.bindPopup(popup_95d3bbb61fac799420dfa670e60f1544)
#         ;
#
#
#
#
#             var poly_line_f004df37687b52814395751142ba40f7 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.63509, -91.0357385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a8a93e9bcce2d674be650c7f2b95b312);
#
#
#         var popup_3d4838eb46e322be8263689f0f57190c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_034bf367d98b4f662212b355fe0c987e = $(`&lt;div id=&quot;html_034bf367d98b4f662212b355fe0c987e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 158128050, NE, 2.088140857598&lt;/div&gt;`)[0];
#                 popup_3d4838eb46e322be8263689f0f57190c.setContent(html_034bf367d98b4f662212b355fe0c987e);
#
#
#
#         poly_line_f004df37687b52814395751142ba40f7.bindPopup(popup_3d4838eb46e322be8263689f0f57190c)
#         ;
#
#
#
#
#             var poly_line_7d2ae5e08d06fb4b5f4181ff4788f65b = L.polyline(
#                 [[41.6048483, -91.0360948], [41.6045679, -91.0361029]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_a8a93e9bcce2d674be650c7f2b95b312);
#
#
#         var popup_7ac7c90e83ed074716d63c21a64516bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea118eb06ee804b3685c61363b664008 = $(`&lt;div id=&quot;html_ea118eb06ee804b3685c61363b664008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, SW, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_7ac7c90e83ed074716d63c21a64516bc.setContent(html_ea118eb06ee804b3685c61363b664008);
#
#
#
#         poly_line_7d2ae5e08d06fb4b5f4181ff4788f65b.bindPopup(popup_7ac7c90e83ed074716d63c21a64516bc)
#         ;
#
#
#
#
#             var poly_line_099db78abd23332d43f2b46edc1b2768 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe3e30d70202357db22b8a553cdbb018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe3e30d70202357db22b8a553cdbb018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe3e30d70202357db22b8a553cdbb018 = L.map(
#                 &quot;map_fe3e30d70202357db22b8a553cdbb018&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89fecb0d085418a3152f0745cd1f8bab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe3e30d70202357db22b8a553cdbb018);
#
#
#             var poly_line_b0d9884890646d5f9b591aeb6cc037c1 = L.polyline(
#                 [[41.6045679, -91.0361029], [41.6048483, -91.0360948]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fe3e30d70202357db22b8a553cdbb018);
#
#
#         var popup_4e30362320519d3ce22d11c223d03bba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e811f117a8e2e1b27b951a40f09fa52 = $(`&lt;div id=&quot;html_2e811f117a8e2e1b27b951a40f09fa52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, NE, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_4e30362320519d3ce22d11c223d03bba.setContent(html_2e811f117a8e2e1b27b951a40f09fa52);
#
#
#
#         poly_line_b0d9884890646d5f9b591aeb6cc037c1.bindPopup(popup_4e30362320519d3ce22d11c223d03bba)
#         ;
#
#
#
#
#             var poly_line_8cd0256d1bba8c0188494f12ddc6df43 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.63509, -91.0357385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fe3e30d70202357db22b8a553cdbb018);
#
#
#         var popup_bcb68b09156456ee2f260be2f8da944d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a19f4415f653158300e9f42372ff819d = $(`&lt;div id=&quot;html_a19f4415f653158300e9f42372ff819d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 158128050, NE, 2.088140857598&lt;/div&gt;`)[0];
#                 popup_bcb68b09156456ee2f260be2f8da944d.setContent(html_a19f4415f653158300e9f42372ff819d);
#
#
#
#         poly_line_8cd0256d1bba8c0188494f12ddc6df43.bindPopup(popup_bcb68b09156456ee2f260be2f8da944d)
#         ;
#
#
#
#
#             var poly_line_faa1ed39860070773c670ead3c51e0d0 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.6045679, -91.0361029]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_fe3e30d70202357db22b8a553cdbb018);
#
#
#         var popup_6a33a98f63af505ab420eed988538d6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad76f152fa0d99404ffba3279f3fa372 = $(`&lt;div id=&quot;html_ad76f152fa0d99404ffba3279f3fa372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, SW, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_6a33a98f63af505ab420eed988538d6b.setContent(html_ad76f152fa0d99404ffba3279f3fa372);
#
#
#
#         poly_line_faa1ed39860070773c670ead3c51e0d0.bindPopup(popup_6a33a98f63af505ab420eed988538d6b)
#         ;
#
#
#
#
#             var poly_line_8e048c9e94755ed39463e547a203abbc = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc48caab6e6be25c041a434457654f29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc48caab6e6be25c041a434457654f29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc48caab6e6be25c041a434457654f29 = L.map(
#                 &quot;map_cc48caab6e6be25c041a434457654f29&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9a616d6bd570826f9921bbff1f44ef5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cc48caab6e6be25c041a434457654f29);
#
#
#             var poly_line_d1e6fe3c8aaacf1d87381f2e0be1ea3b = L.polyline(
#                 [[41.6045679, -91.0361029], [41.6048483, -91.0360948]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_cc48caab6e6be25c041a434457654f29);
#
#
#         var popup_d15fd50a6d0066bbc87049ae430d0082 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d5309e973d773b91e5cf34ceb29b604 = $(`&lt;div id=&quot;html_5d5309e973d773b91e5cf34ceb29b604&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 460627025, NE, 0.019363784473000002&lt;/div&gt;`)[0];
#                 popup_d15fd50a6d0066bbc87049ae430d0082.setContent(html_5d5309e973d773b91e5cf34ceb29b604);
#
#
#
#         poly_line_d1e6fe3c8aaacf1d87381f2e0be1ea3b.bindPopup(popup_d15fd50a6d0066bbc87049ae430d0082)
#         ;
#
#
#
#
#             var poly_line_c2b15f5dba87400a3aca0066f3f112b6 = L.polyline(
#                 [[41.6048483, -91.0360948], [41.63509, -91.0357385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_cc48caab6e6be25c041a434457654f29);
#
#
#         var popup_30bc6c8214ac92eaf041e336022fd5a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9643b44a6b56e3d3a1b7eb8b20660d11 = $(`&lt;div id=&quot;html_9643b44a6b56e3d3a1b7eb8b20660d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 158128050, NE, 2.088140857598&lt;/div&gt;`)[0];
#                 popup_30bc6c8214ac92eaf041e336022fd5a7.setContent(html_9643b44a6b56e3d3a1b7eb8b20660d11);
#
#
#
#         poly_line_c2b15f5dba87400a3aca0066f3f112b6.bindPopup(popup_30bc6c8214ac92eaf041e336022fd5a7)
#         ;
#
#
#
#
#             var poly_line_e0aee8740fabdfdb1e0976a3ef4d9997 = L.polyline(
#                 [[41.63509, -91.0357385], [41.6048483, -91.0360948]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_cc48caab6e6be25c041a434457654f29);
#
#
#         var popup_ab640e4c26b6bb18ba33ad45f136f616 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6409c3f0c4b8b2ce807c4c76406edb4d = $(`&lt;div id=&quot;html_6409c3f0c4b8b2ce807c4c76406edb4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;US 6, 158128050, SW, 2.088140857598&lt;/div&gt;`)[0];
#                 popup_ab640e4c26b6bb18ba33ad45f136f616.setContent(html_6409c3f0c4b8b2ce807c4c76406edb4d);
#
#
#
#         poly_line_e0aee8740fabdfdb1e0976a3ef4d9997.bindPopup(popup_ab640e4c26b6bb18ba33ad45f136f616)
#         ;
#
#
#
#
#             map_cc48caab6e6be25c041a434457654f29.fitBounds(
#                 [[41.604567

# %%
maps = mapper.router.routeMaps(42.293894, -84.275253, 42.271693, -84.847918)
for mp in maps[:-15]:
    display(mp)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac51b3a8215e407a4a08196c2cf4fd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac51b3a8215e407a4a08196c2cf4fd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac51b3a8215e407a4a08196c2cf4fd3 = L.map(
#                 &quot;map_bac51b3a8215e407a4a08196c2cf4fd3&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffd3da5383e83ba49f11ba65b25a424b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bac51b3a8215e407a4a08196c2cf4fd3);
#
#
#             var poly_line_f145f5cab9648aaf125348811a99881d = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_bac51b3a8215e407a4a08196c2cf4fd3);
#
#
#         var popup_1f27747a5cc2c3113f86cd8124ecaea9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dbb8cd9af2b6fddb7868c319f430d3f9 = $(`&lt;div id=&quot;html_dbb8cd9af2b6fddb7868c319f430d3f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_1f27747a5cc2c3113f86cd8124ecaea9.setContent(html_dbb8cd9af2b6fddb7868c319f430d3f9);
#
#
#
#         poly_line_f145f5cab9648aaf125348811a99881d.bindPopup(popup_1f27747a5cc2c3113f86cd8124ecaea9)
#         ;
#
#
#
#
#             var poly_line_6c8f47d974bd2b3a0417267dfdcde6fc = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_bac51b3a8215e407a4a08196c2cf4fd3);
#
#
#         var popup_a5f8007e049d63c51de1471e57901dbe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83f2b2cf2674866ab042e96098b0ee4d = $(`&lt;div id=&quot;html_83f2b2cf2674866ab042e96098b0ee4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_a5f8007e049d63c51de1471e57901dbe.setContent(html_83f2b2cf2674866ab042e96098b0ee4d);
#
#
#
#         poly_line_6c8f47d974bd2b3a0417267dfdcde6fc.bindPopup(popup_a5f8007e049d63c51de1471e57901dbe)
#         ;
#
#
#
#
#             map_bac51b3a8215e407a4a08196c2cf4fd3.fitBounds(
#                 [[42.2768726, -84.3661974], [42.2918595, -84.2601946]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9c6e882a82931dc2d43a90e96d3dd69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9c6e882a82931dc2d43a90e96d3dd69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9c6e882a82931dc2d43a90e96d3dd69 = L.map(
#                 &quot;map_d9c6e882a82931dc2d43a90e96d3dd69&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b321942e6686299de6202e90f662fa4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9c6e882a82931dc2d43a90e96d3dd69);
#
#
#             var poly_line_c0cc62f63acf8b476e84fdbe018f8f23 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_d9c6e882a82931dc2d43a90e96d3dd69);
#
#
#         var popup_73f96275ccdc6d7e481768777332dec8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d083ed9e8e9936b37f20264bf2377620 = $(`&lt;div id=&quot;html_d083ed9e8e9936b37f20264bf2377620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_73f96275ccdc6d7e481768777332dec8.setContent(html_d083ed9e8e9936b37f20264bf2377620);
#
#
#
#         poly_line_c0cc62f63acf8b476e84fdbe018f8f23.bindPopup(popup_73f96275ccdc6d7e481768777332dec8)
#         ;
#
#
#
#
#             var poly_line_4b3e0b4039206ed859d96ac4af759555 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_d9c6e882a82931dc2d43a90e96d3dd69);
#
#
#         var popup_42ce37f05597905c695c64f3da99a1f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab0cbb6be076bff094d88911b4a4a31c = $(`&lt;div id=&quot;html_ab0cbb6be076bff094d88911b4a4a31c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_42ce37f05597905c695c64f3da99a1f3.setContent(html_ab0cbb6be076bff094d88911b4a4a31c);
#
#
#
#         poly_line_4b3e0b4039206ed859d96ac4af759555.bindPopup(popup_42ce37f05597905c695c64f3da99a1f3)
#         ;
#
#
#
#
#             var poly_line_5b48a51c69c146adff932ffbb0447985 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_d9c6e882a82931dc2d43a90e96d3dd69);
#
#
#         var popup_54ae07134dd0afdbf5702b788e78cbf0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0656d28887da6e9f91dc93ce5314fe2d = $(`&lt;div id=&quot;html_0656d28887da6e9f91dc93ce5314fe2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_54ae07134dd0afdbf5702b788e78cbf0.setContent(html_0656d28887da6e9f91dc93ce5314fe2d);
#
#
#
#         poly_line_5b48a51c69c146adff932ffbb0447985.bindPopup(popup_54ae07134dd0afdbf5702b788e78cbf0)
#         ;
#
#
#
#
#             map_d9c6e882a82931dc2d43a90e96d3dd69.fitBounds(
#                 [[42
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b88b9d75bce2e6fec4f18921a5035cc2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b88b9d75bce2e6fec4f18921a5035cc2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b88b9d75bce2e6fec4f18921a5035cc2 = L.map(
#                 &quot;map_b88b9d75bce2e6fec4f18921a5035cc2&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9336dd470e142f3056f95156cb8229e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b88b9d75bce2e6fec4f18921a5035cc2);
#
#
#             var poly_line_b73506b5deaf0625cd809880abb96d71 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b88b9d75bce2e6fec4f18921a5035cc2);
#
#
#         var popup_e96c9beaf4876301c86ee23820159b79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b294a9995ee23ef27ababffec8251ed2 = $(`&lt;div id=&quot;html_b294a9995ee23ef27ababffec8251ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_e96c9beaf4876301c86ee23820159b79.setContent(html_b294a9995ee23ef27ababffec8251ed2);
#
#
#
#         poly_line_b73506b5deaf0625cd809880abb96d71.bindPopup(popup_e96c9beaf4876301c86ee23820159b79)
#         ;
#
#
#
#
#             var poly_line_037c5f8f09af83c2891f8dea4867c413 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b88b9d75bce2e6fec4f18921a5035cc2);
#
#
#         var popup_a012df57e1f2ce5b77049eea587e69c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fe80bcd98549ce727aa6af8c291d87f2 = $(`&lt;div id=&quot;html_fe80bcd98549ce727aa6af8c291d87f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_a012df57e1f2ce5b77049eea587e69c8.setContent(html_fe80bcd98549ce727aa6af8c291d87f2);
#
#
#
#         poly_line_037c5f8f09af83c2891f8dea4867c413.bindPopup(popup_a012df57e1f2ce5b77049eea587e69c8)
#         ;
#
#
#
#
#             var poly_line_1412f9269e81a30b5c1afcf49abf0381 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;pink&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;pink&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b88b9d75bce2e6fec4f18921a5035cc2);
#
#
#         var popup_91489f6a56a75b1a66f4176416865121 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad6bf6aec53babd8f61199f955dec766 = $(`&lt;div id=&quot;html_ad6bf6aec53babd8f61199f955dec766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_91489f6a56a75b1a66f4176416865121.setContent(html_ad6bf6aec53babd8f61199f955dec766);
#
#
#
#         poly_line_1412f9269e81a30b5c1afcf49abf0381.bindPopup(popup_91489f6a56a75b1a66f4176416865121)
#         ;
#
#
#
#
#             var poly_line_a9f618b5cec05ff18b032bc0f2810084 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59a79e6bf93c52c86b61aa0a7e568f70 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59a79e6bf93c52c86b61aa0a7e568f70&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59a79e6bf93c52c86b61aa0a7e568f70 = L.map(
#                 &quot;map_59a79e6bf93c52c86b61aa0a7e568f70&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2adca2e3e16e2f340bb70ac07686298 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_59a79e6bf93c52c86b61aa0a7e568f70);
#
#
#             var poly_line_1bf6be16135be557a8d9bd9aadc5a159 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_59a79e6bf93c52c86b61aa0a7e568f70);
#
#
#         var popup_cb71a4d76c1bd11a7748952bc60db11f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae7b28b215fb21535869fa6115e66ce4 = $(`&lt;div id=&quot;html_ae7b28b215fb21535869fa6115e66ce4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_cb71a4d76c1bd11a7748952bc60db11f.setContent(html_ae7b28b215fb21535869fa6115e66ce4);
#
#
#
#         poly_line_1bf6be16135be557a8d9bd9aadc5a159.bindPopup(popup_cb71a4d76c1bd11a7748952bc60db11f)
#         ;
#
#
#
#
#             var poly_line_45c21310bb37c182a591d7ff56918e03 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_59a79e6bf93c52c86b61aa0a7e568f70);
#
#
#         var popup_2af1e1b25d9e934539fd4bc55417274d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc45e55d66821377dd72f81e46624031 = $(`&lt;div id=&quot;html_fc45e55d66821377dd72f81e46624031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_2af1e1b25d9e934539fd4bc55417274d.setContent(html_fc45e55d66821377dd72f81e46624031);
#
#
#
#         poly_line_45c21310bb37c182a591d7ff56918e03.bindPopup(popup_2af1e1b25d9e934539fd4bc55417274d)
#         ;
#
#
#
#
#             var poly_line_2c8956c4e90a84843a829aaf653918ba = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_59a79e6bf93c52c86b61aa0a7e568f70);
#
#
#         var popup_7e39f38e41b3481bf0be004d6c778974 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb71559d98f245c6919cdb97a377256b = $(`&lt;div id=&quot;html_eb71559d98f245c6919cdb97a377256b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_7e39f38e41b3481bf0be004d6c778974.setContent(html_eb71559d98f245c6919cdb97a377256b);
#
#
#
#         poly_line_2c8956c4e90a84843a829aaf653918ba.bindPopup(popup_7e39f38e41b3481bf0be004d6c778974)
#         ;
#
#
#
#
#             var poly_line_7b8d4a96732952bca87c3e4a3f612b8f = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c692d77cbb94934872f4e31b83091abe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c692d77cbb94934872f4e31b83091abe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c692d77cbb94934872f4e31b83091abe = L.map(
#                 &quot;map_c692d77cbb94934872f4e31b83091abe&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2e09bf1aa5a213017e1977987fbdf40 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c692d77cbb94934872f4e31b83091abe);
#
#
#             var poly_line_4e6427cecb8923332fec20a17dfc4675 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c692d77cbb94934872f4e31b83091abe);
#
#
#         var popup_95b191291be856d1bbe0a35a11fa8020 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a0329d45ccdfff960df4ff02d6e4df5 = $(`&lt;div id=&quot;html_0a0329d45ccdfff960df4ff02d6e4df5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_95b191291be856d1bbe0a35a11fa8020.setContent(html_0a0329d45ccdfff960df4ff02d6e4df5);
#
#
#
#         poly_line_4e6427cecb8923332fec20a17dfc4675.bindPopup(popup_95b191291be856d1bbe0a35a11fa8020)
#         ;
#
#
#
#
#             var poly_line_95fd11a343a9d8a5edb54e80dce0b344 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c692d77cbb94934872f4e31b83091abe);
#
#
#         var popup_be9d02a6f480d5b201c64c5d401d39bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7168c9f12e8ec6eb53cac994131be321 = $(`&lt;div id=&quot;html_7168c9f12e8ec6eb53cac994131be321&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_be9d02a6f480d5b201c64c5d401d39bd.setContent(html_7168c9f12e8ec6eb53cac994131be321);
#
#
#
#         poly_line_95fd11a343a9d8a5edb54e80dce0b344.bindPopup(popup_be9d02a6f480d5b201c64c5d401d39bd)
#         ;
#
#
#
#
#             var poly_line_f209f48ed32f5c7b5fb807d868ca47dc = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_c692d77cbb94934872f4e31b83091abe);
#
#
#         var popup_5d42b4ddd0f8f005fe9cd28d841d2987 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4aa369ca3f4f53275369466babcc5d4f = $(`&lt;div id=&quot;html_4aa369ca3f4f53275369466babcc5d4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_5d42b4ddd0f8f005fe9cd28d841d2987.setContent(html_4aa369ca3f4f53275369466babcc5d4f);
#
#
#
#         poly_line_f209f48ed32f5c7b5fb807d868ca47dc.bindPopup(popup_5d42b4ddd0f8f005fe9cd28d841d2987)
#         ;
#
#
#
#
#             var poly_line_cdc64d3efc916bf533d5295b71fb2077 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6856967a8cbb1bd2ef48ac2a56300740 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6856967a8cbb1bd2ef48ac2a56300740&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6856967a8cbb1bd2ef48ac2a56300740 = L.map(
#                 &quot;map_6856967a8cbb1bd2ef48ac2a56300740&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77e8c2916d9b83e16f90fb73fe67ad6b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6856967a8cbb1bd2ef48ac2a56300740);
#
#
#             var poly_line_f7c650982617cff7bbd241e95250fada = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6856967a8cbb1bd2ef48ac2a56300740);
#
#
#         var popup_d8294a88e8a4d1f297c48a0138f53400 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_986ed14f601e63a637a64b050f6a26d1 = $(`&lt;div id=&quot;html_986ed14f601e63a637a64b050f6a26d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_d8294a88e8a4d1f297c48a0138f53400.setContent(html_986ed14f601e63a637a64b050f6a26d1);
#
#
#
#         poly_line_f7c650982617cff7bbd241e95250fada.bindPopup(popup_d8294a88e8a4d1f297c48a0138f53400)
#         ;
#
#
#
#
#             var poly_line_2bae5bd6b52766f5d3ca6180f61688d1 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6856967a8cbb1bd2ef48ac2a56300740);
#
#
#         var popup_e32caaa99d561987a28236eb2fa95aac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8642709f32fd9f0ffffeed098d0a5b51 = $(`&lt;div id=&quot;html_8642709f32fd9f0ffffeed098d0a5b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_e32caaa99d561987a28236eb2fa95aac.setContent(html_8642709f32fd9f0ffffeed098d0a5b51);
#
#
#
#         poly_line_2bae5bd6b52766f5d3ca6180f61688d1.bindPopup(popup_e32caaa99d561987a28236eb2fa95aac)
#         ;
#
#
#
#
#             var poly_line_058900374cdca991fafabd9884990d10 = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_6856967a8cbb1bd2ef48ac2a56300740);
#
#
#         var popup_4b9605409d481d2af85095e81f0f0d4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cbeebb0066ad74c62134c347648d8bf6 = $(`&lt;div id=&quot;html_cbeebb0066ad74c62134c347648d8bf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_4b9605409d481d2af85095e81f0f0d4b.setContent(html_cbeebb0066ad74c62134c347648d8bf6);
#
#
#
#         poly_line_058900374cdca991fafabd9884990d10.bindPopup(popup_4b9605409d481d2af85095e81f0f0d4b)
#         ;
#
#
#
#
#             var poly_line_6973a6c9dfd7208444de21e4a5863303 = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31ce6666e94596092c42da33af743409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31ce6666e94596092c42da33af743409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31ce6666e94596092c42da33af743409 = L.map(
#                 &quot;map_31ce6666e94596092c42da33af743409&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d26c6179fd3b5ca5f5bb3be65ec4ede1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31ce6666e94596092c42da33af743409);
#
#
#             var poly_line_6f08e02c7f83d4b95861385bf426ad91 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_31ce6666e94596092c42da33af743409);
#
#
#         var popup_3a686993aaffd31e4fef77cee301b4a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9879a17735dd3e6827f0a07dd5dff969 = $(`&lt;div id=&quot;html_9879a17735dd3e6827f0a07dd5dff969&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_3a686993aaffd31e4fef77cee301b4a4.setContent(html_9879a17735dd3e6827f0a07dd5dff969);
#
#
#
#         poly_line_6f08e02c7f83d4b95861385bf426ad91.bindPopup(popup_3a686993aaffd31e4fef77cee301b4a4)
#         ;
#
#
#
#
#             var poly_line_420d0a63972d220d689de7bdfb035643 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_31ce6666e94596092c42da33af743409);
#
#
#         var popup_26a44998151155c5ab0b687992d48486 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c1702943d79cb138c951564383acde0 = $(`&lt;div id=&quot;html_7c1702943d79cb138c951564383acde0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_26a44998151155c5ab0b687992d48486.setContent(html_7c1702943d79cb138c951564383acde0);
#
#
#
#         poly_line_420d0a63972d220d689de7bdfb035643.bindPopup(popup_26a44998151155c5ab0b687992d48486)
#         ;
#
#
#
#
#             var poly_line_034832966ca1358dfccabfc13a8addec = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_31ce6666e94596092c42da33af743409);
#
#
#         var popup_68a74bd67e1c18ead64f2ac279229231 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61620c7a4f84fcb022182c53975027e4 = $(`&lt;div id=&quot;html_61620c7a4f84fcb022182c53975027e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_68a74bd67e1c18ead64f2ac279229231.setContent(html_61620c7a4f84fcb022182c53975027e4);
#
#
#
#         poly_line_034832966ca1358dfccabfc13a8addec.bindPopup(popup_68a74bd67e1c18ead64f2ac279229231)
#         ;
#
#
#
#
#             var poly_line_913e800a4bd7a9773bfcbb34c26c18ef = L.polyline(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f73cd7903c22a1f872c2c65e5dbb5a66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f73cd7903c22a1f872c2c65e5dbb5a66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f73cd7903c22a1f872c2c65e5dbb5a66 = L.map(
#                 &quot;map_f73cd7903c22a1f872c2c65e5dbb5a66&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b2d9f9f1cf7c72494bb001864db2ac1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f73cd7903c22a1f872c2c65e5dbb5a66);
#
#
#             var poly_line_f234defbec86605a310de667ef90b346 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f73cd7903c22a1f872c2c65e5dbb5a66);
#
#
#         var popup_effbec4a4b95252f4e4241e19d0cd137 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d5fd4f44835bd07c5ee10e8ecd05bca = $(`&lt;div id=&quot;html_0d5fd4f44835bd07c5ee10e8ecd05bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_effbec4a4b95252f4e4241e19d0cd137.setContent(html_0d5fd4f44835bd07c5ee10e8ecd05bca);
#
#
#
#         poly_line_f234defbec86605a310de667ef90b346.bindPopup(popup_effbec4a4b95252f4e4241e19d0cd137)
#         ;
#
#
#
#
#             var poly_line_1addcf486042e9d5e44147ca62ecb904 = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f73cd7903c22a1f872c2c65e5dbb5a66);
#
#
#         var popup_fbcd744e31761491885038cc58e5676e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d5797a9df1c04bf38a3ead9d63c7054 = $(`&lt;div id=&quot;html_5d5797a9df1c04bf38a3ead9d63c7054&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_fbcd744e31761491885038cc58e5676e.setContent(html_5d5797a9df1c04bf38a3ead9d63c7054);
#
#
#
#         poly_line_1addcf486042e9d5e44147ca62ecb904.bindPopup(popup_fbcd744e31761491885038cc58e5676e)
#         ;
#
#
#
#
#             var poly_line_3b0eb249ea28c115bdebc67fc7d0124c = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f73cd7903c22a1f872c2c65e5dbb5a66);
#
#
#         var popup_b7feb401ef880d29c8a78f42d45f32f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f143b66ee073fc103cc132ddbdeb7bb5 = $(`&lt;div id=&quot;html_f143b66ee073fc103cc132ddbdeb7bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_b7feb401ef880d29c8a78f42d45f32f6.setContent(html_f143b66ee073fc103cc132ddbdeb7bb5);
#
#
#
#         poly_line_3b0eb249ea28c115bdebc67fc7d0124c.bindPopup(popup_b7feb401ef880d29c8a78f42d45f32f6)
#         ;
#
#
#
#
#             var poly_line_9f7abba33ba9b974315a14b9e25843ea = L.polyline(
