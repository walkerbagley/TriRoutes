# %%
import folium
from mapping import mapper

# %%
mapper = mapper()

# %%
m = mapper.mapRoute([42.293894, -84.275253], [42.271693, -84.847918])
m
# Out:
# Expected Distance 31.52 miles
# Expected Time: 27 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d3b465c477ed72d72c11013db6777f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d3b465c477ed72d72c11013db6777f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d3b465c477ed72d72c11013db6777f5 = L.map(
#                 &quot;map_4d3b465c477ed72d72c11013db6777f5&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1f20d9a7cd5f533140c86246aff8f2f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d3b465c477ed72d72c11013db6777f5);
#
#
#             var poly_line_7d3fa37e69c8c5a0928f56b17405ef29 = L.polyline(
#                 [[42.2918595, -84.2601946], [42.2773942, -84.3216809]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4d3b465c477ed72d72c11013db6777f5);
#
#
#         var popup_6859b91d0f58deadf761b732be63af65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2bf1fb03b6ee172d9a5441d7beaf5f4b = $(`&lt;div id=&quot;html_2bf1fb03b6ee172d9a5441d7beaf5f4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 60733805, SW, 3.365964221516&lt;/div&gt;`)[0];
#                 popup_6859b91d0f58deadf761b732be63af65.setContent(html_2bf1fb03b6ee172d9a5441d7beaf5f4b);
#
#
#
#         poly_line_7d3fa37e69c8c5a0928f56b17405ef29.bindPopup(popup_6859b91d0f58deadf761b732be63af65)
#         ;
#
#
#
#
#             var poly_line_18b5bb29fb453956029cb5b404e51bcb = L.polyline(
#                 [[42.2773942, -84.3216809], [42.2768726, -84.3661974]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4d3b465c477ed72d72c11013db6777f5);
#
#
#         var popup_8de73428e66a2b250929ab73251e5735 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f525e69043faf8c7c6e7f8c58f990eaf = $(`&lt;div id=&quot;html_f525e69043faf8c7c6e7f8c58f990eaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94, 740319768, SW, 2.2747242773650003&lt;/div&gt;`)[0];
#                 popup_8de73428e66a2b250929ab73251e5735.setContent(html_f525e69043faf8c7c6e7f8c58f990eaf);
#
#
#
#         poly_line_18b5bb29fb453956029cb5b404e51bcb.bindPopup(popup_8de73428e66a2b250929ab73251e5735)
#         ;
#
#
#
#
#             var poly_line_97c1a9a5c0dc7c59d9f3c6ceddfd1a3f = L.polyline(
#                 [[42.2768726, -84.3661974], [42.2715138, -84.4068168]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4d3b465c477ed72d72c11013db6777f5);
#
#
#         var popup_b6a52ab36bc93f335269071abd5eac23 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c451c6e89d88e9ad5b17fed49d48fd9f = $(`&lt;div id=&quot;html_c451c6e89d88e9ad5b17fed49d48fd9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 94;US 127, 41007438, SW, 2.114280692826&lt;/div&gt;`)[0];
#                 popup_b6a52ab36bc93f335269071abd5eac23.setContent(html_c451c6e89d88e9ad5b17fed49d48fd9f);
#
#
#
#         poly_line_97c1a9a5c0dc7c59d9f3c6ceddfd1a3f.bindPopup(popup_b6a52ab36bc93f335269071abd5eac23)
#         ;
#
#
#
#
#             var poly_line_e1f786af7fd721c18d68e3f2e13a82a0 =

# %%
m = mapper.mapRoute([35.128556, -111.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 129.59 miles
# Expected Time: 1 hrs 43 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_665d3619fbf4efe4c3415ce8eb8dde26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_665d3619fbf4efe4c3415ce8eb8dde26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_665d3619fbf4efe4c3415ce8eb8dde26 = L.map(
#                 &quot;map_665d3619fbf4efe4c3415ce8eb8dde26&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72b48187f69927146c8ebe4058f802ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_665d3619fbf4efe4c3415ce8eb8dde26);
#
#
#             var poly_line_2559830bf23ac778a951e9f2d880171e = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_665d3619fbf4efe4c3415ce8eb8dde26);
#
#
#         var popup_63b0f41c0f4d34ab558d53ba84cab544 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d9fa9d6178d2d5c0a47bb24e5e900e98 = $(`&lt;div id=&quot;html_d9fa9d6178d2d5c0a47bb24e5e900e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 849020694, SE, 0.405516035165&lt;/div&gt;`)[0];
#                 popup_63b0f41c0f4d34ab558d53ba84cab544.setContent(html_d9fa9d6178d2d5c0a47bb24e5e900e98);
#
#
#
#         poly_line_2559830bf23ac778a951e9f2d880171e.bindPopup(popup_63b0f41c0f4d34ab558d53ba84cab544)
#         ;
#
#
#
#
#             var poly_line_24162eb383b9edd96afca1ada0de9d70 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_665d3619fbf4efe4c3415ce8eb8dde26);
#
#
#         var popup_23b7f4d437893e1a8ba789c01f07003c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_64a1bb044b6cac1484915cda31772f85 = $(`&lt;div id=&quot;html_64a1bb044b6cac1484915cda31772f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447120, SE, 0.015121684655999999&lt;/div&gt;`)[0];
#                 popup_23b7f4d437893e1a8ba789c01f07003c.setContent(html_64a1bb044b6cac1484915cda31772f85);
#
#
#
#         poly_line_24162eb383b9edd96afca1ada0de9d70.bindPopup(popup_23b7f4d437893e1a8ba789c01f07003c)
#         ;
#
#
#
#
#             var poly_line_45303ac99c7b2bcaa930620e66bbbcf6 = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_665d3619fbf4efe4c3415ce8eb8dde26);
#
#
#         var popup_fe04941ac258c852de8b97c5c9fc5276 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39bc84a1233069edeca624f144aa9c59 = $(`&lt;div id=&quot;html_39bc84a1233069edeca624f144aa9c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447112, SE, 0.36979217363300004&lt;/div&gt;`)[0];
#                 popup_fe04941ac258c852de8b97c5c9fc5276.setContent(html_39bc84a1233069edeca624f144aa9c59);
#
#
#
#         poly_line_45303ac99c7b2bcaa930620e66bbbcf6.bindPopup(popup_fe04941ac258c852de8b97c5c9fc5276)
#         ;
#
#
#
#
#             var poly_line_f969dd

# %%
m = mapper.mapRoute([34.928556, -115.200147], [35.054526, -108.802710])
m
# Out:
# Expected Distance 297.64 miles
# Expected Time: 3 hrs 59 min
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f310c17b933c54cc403959d849766a72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f310c17b933c54cc403959d849766a72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f310c17b933c54cc403959d849766a72 = L.map(
#                 &quot;map_f310c17b933c54cc403959d849766a72&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f59ee81eebc162544a98e621b9e52c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f310c17b933c54cc403959d849766a72);
#
#
#             var poly_line_9e3294d0c5d4801d4b9d82ca69c6e5c7 = L.polyline(
#                 [[35.133652, -111.1966896], [35.1312375, -111.1901426]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f310c17b933c54cc403959d849766a72);
#
#
#         var popup_2defa13ea884a85d1ecc7e9f305997e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1c7ada9a41f0d1f18b88be299ccd99d = $(`&lt;div id=&quot;html_b1c7ada9a41f0d1f18b88be299ccd99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 849020694, SE, 0.405516035165&lt;/div&gt;`)[0];
#                 popup_2defa13ea884a85d1ecc7e9f305997e8.setContent(html_b1c7ada9a41f0d1f18b88be299ccd99d);
#
#
#
#         poly_line_9e3294d0c5d4801d4b9d82ca69c6e5c7.bindPopup(popup_2defa13ea884a85d1ecc7e9f305997e8)
#         ;
#
#
#
#
#             var poly_line_68196705f862ccc50582234ed0e06d72 = L.polyline(
#                 [[35.1312375, -111.1901426], [35.1311513, -111.1898964]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f310c17b933c54cc403959d849766a72);
#
#
#         var popup_6b3b8e2bd072bd6c7e466ebbaba8b3ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8503e86baaa6967a16a688f125a9e0a6 = $(`&lt;div id=&quot;html_8503e86baaa6967a16a688f125a9e0a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447120, SE, 0.015121684655999999&lt;/div&gt;`)[0];
#                 popup_6b3b8e2bd072bd6c7e466ebbaba8b3ac.setContent(html_8503e86baaa6967a16a688f125a9e0a6);
#
#
#
#         poly_line_68196705f862ccc50582234ed0e06d72.bindPopup(popup_6b3b8e2bd072bd6c7e466ebbaba8b3ac)
#         ;
#
#
#
#
#             var poly_line_67da091fb849285befc028309b547e2f = L.polyline(
#                 [[35.1311513, -111.1898964], [35.1289647, -111.1839182]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_f310c17b933c54cc403959d849766a72);
#
#
#         var popup_955f1d466326b0e3f38ce2c0363f003e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdbed2efde501b548746dda859fa56b5 = $(`&lt;div id=&quot;html_cdbed2efde501b548746dda859fa56b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;I 40;US 180, 144447112, SE, 0.36979217363300004&lt;/div&gt;`)[0];
#                 popup_955f1d466326b0e3f38ce2c0363f003e.setContent(html_cdbed2efde501b548746dda859fa56b5);
#
#
#
#         poly_line_67da091fb849285befc028309b547e2f.bindPopup(popup_955f1d466326b0e3f38ce2c0363f003e)
#         ;
#
#
#
#
#             var poly_line_446ac2
